# %% [markdown]
# See, e.g., https://danvatterott.com/blog/2016/02/21/grouping-nba-players/ -- very helpful

# %%
import os, sys
sys.path.insert(0, '/Users/kv/workspace/kv-capstone/NBAwinshare/source')

from source import seasonalregressor, data_wrangle
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sb
import pickle
from sklearn.metrics import mean_squared_error
# %matplotlib inline

advanced = data_wrangle.read_all_advanced('./data/advanced')
pergame  = data_wrangle.read_all_pergame('./data/per_game')
seasonal = data_wrangle.clean_and_join_seasonal_dataframe(advanced, pergame)
demographic = data_wrangle.read_demographic_data('./data/player_data.csv')
fullstats = data_wrangle.add_years_in_league(seasonal, demographic)

cols_to_train_from_correlation = ['WS',
 'OWS',
 'VORP',
 'DWS',
 'MP_total',
 'PS/G',
 'FG',
 'MP_pergame',
 'GS',
 'FT',
 '2P',
 'FTA',
 'FGA',
 '2PA',
 'DRB']

with open('train_test.pkl', 'rb') as f:  # Python 3: open(..., 'rb')
    trainnames, testnames = pickle.load(f)
    
actuals = data_wrangle.get_actuals_for_years_5_thru_9(fullstats, testnames)

# %%
sr3 = seasonalregressor.SeasonalRegressor(columns_to_train=cols_to_train_from_correlation)
fulltrain, fulltest = sr3.create_train_test_split(fullstats, trainnames, testnames)

# %%
df, y, _ = sr3.create_train_and_predict_X_and_y_of_first_four_seasons(fullstats, 5)
# Out:
# Number of players:  578  with full season data for seasons: {1, 2, 3, 4, 5}
# Indices of train set and to-predict set MATCH
# Using all columns

# %%
df.head()
# Out:
# Player          A.J. Price  Aaron Gray  Adonal Foyle  Adrian Griffin  \
# Age               24.50000    24.50000      23.50000        26.50000
# G                 51.75000    47.50000      58.25000        62.00000
# MP_total         876.50000   542.50000    1095.25000      1265.00000
# PER               12.15000    13.25000      11.55000        12.20000
# TS%                0.48475     0.53850       0.44750         0.48575
# 3PAr               0.48700     0.00275       0.00150         0.15675
# FTr                0.20400     0.38050       0.30100         0.21525
# ORB%               2.02500    14.02500      11.47500         6.97500
# DRB%               8.77500    22.32500      18.92500        15.35000
# TRB%               5.37500    18.12500      15.02500        11.07500
# AST%              23.37500     9.07500       4.35000        11.85000
# STL%               1.75000     1.35000       1.05000         2.82500
# BLK%               0.20000     2.10000       6.00000         0.62500
# TOV%              13.35000    18.45000      17.20000        13.05000
# USG%              20.27500    16.50000      13.87500        13.77500
# OWS                0.30000     0.35000      -0.25000         1.25000
# DWS                0.80000     0.70000       1.15000         1.42500
# WS                 1.10000     1.02500       0.90000         2.67500
# WSp48              0.05800     0.09850       0.03875         0.09375
# OBPM              -0.30000    -2.05000      -4.70000        -0.90000
# DBPM              -1.92500     0.87500       2.42500         1.42500
# BPM               -2.22500    -1.15000      -2.30000         0.52500
# VORP              -0.05000     0.07500      -0.02500         1.05000
# Season          2011.50000  2009.50000    1999.50000      2001.50000
# GS                 6.25000     6.25000      24.25000        32.25000
# MP_pergame        16.65000    11.37500      18.20000        19.45000
# FG                 2.25000     1.45000       1.92500         2.07500
# FGA                5.97500     2.82500       4.35000         4.67500
# FG%                0.37375     0.51700       0.44000         0.42400
# 3P                 0.92500     0.00000       0.00000         0.20000
# 3PA                2.90000     0.00000       0.00000         0.65000
# 3P%                0.31625     0.00000       0.00000         0.29325
# 2P                 1.35000     1.45000       1.92500         1.85000
# 2PA                3.07500     2.82500       4.35000         4.00000
# 2P%                0.42750     0.51825       0.44050         0.44150
# eFG%               0.45075     0.51700       0.44000         0.44825
# FT                 0.92500     0.62500       0.50000         0.80000
# FTA                1.20000     1.10000       1.17500         0.97500
# FT%                0.76425     0.58900       0.43600         0.79600
# ORB                0.30000     1.35000       2.02500         1.20000
# DRB                1.30000     2.15000       3.05000         2.50000
# TRB                1.60000     3.55000       5.07500         3.67500
# AST                2.42500     0.65000       0.52500         1.57500
# STL                0.57500     0.30000       0.32500         1.07500
# BLK                0.05000     0.30000       1.60000         0.15000
# TOV                1.00000     0.75000       0.97500         0.75000
# PF                 1.02500     2.07500       2.22500         2.15000
# PS/G               6.35000     3.55000       4.32500         5.10000
# Seasons_number     2.50000     2.50000       2.50000         2.50000
# kmeans_label       4.00000     9.00000       7.00000         1.00000
#
# Player          Al Harrington
# Age                  19.50000
# G                    48.25000
# MP_total           1054.75000
# PER                  10.42500
# TS%                   0.47200
# 3PAr                  0.05925
# FTr                   0.31875
# ORB%                  9.35000
# DRB%                 14.57500
# TRB%                 12.05000
# AST%                  7.85000
# STL%                  1.57500
# BLK%                  0.85000
# TOV%                 16.02500
# USG%                 20.62500
# OWS                   0.00000
# DWS                   1.15000
# WS                    1.15000
# WSp48                 0.03325
# OBPM                 -2.70000
# DBPM                 -0.45000
# BPM                  -3.15000
# VORP                 -0.05000
# Season             2000.50000
# GS                    9.75000
# MP_pergame           19.70000
# FG                    2.90000
# FGA                   6.50000
# FG%                   0.42450
# 3P                    0.05000
# 3PA                   0.27500
# 3P%                   0.17775
# 2P                    2.87500
# 2PA                   6.20000
# 2P%                   0.44200
# eFG%                  0.42875
# FT                    1.47500
# FTA                   2.05000
# FT%                   0.68950
# ORB                   1.40000
# DRB                   2.65000
# TRB                   4.07500
# AST                   0.97500
# STL                   0.60000
# BLK                   0.25000
# TOV                   1.37500
# PF                    2.62500
# PS/G                  7.32500
# Seasons_number        2.50000
# kmeans_label          1.00000

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

X = df.values #take data out of dataframe
X = scale(X) #standardize the data before giving it to the PCA.

pca = PCA()
pca.fit(X) #pull out principle components
var_expl = pca.explained_variance_ratio_ #find amount of variance explained by each component
tot_var_expl = np.array([sum(var_expl[0:i+1]) for i,x in enumerate(var_expl)]) #create vector with cumulative variance

plt.figure(figsize=(12,4)) #create cumulative proportion of variance plot
plt.subplot(1,2,1)
plt.plot(range(1,len(tot_var_expl)+1), tot_var_expl*100,'o-')
plt.axis([0, len(tot_var_expl)+1, 0, 100])
plt.xlabel('Number of PCA Components Included')
plt.ylabel('Percentage of variance explained (%)')

plt.subplot(1,2,2) 
plt.plot(range(1,len(var_expl)+1), var_expl*100,'o-')
plt.axis([0, len(var_expl)+1, 0, 100])
plt.xlabel('PCA Component');

# %% [markdown]
# Looks like we get 95% of the variance explained around the 14-15 mark

# %%
np.cumsum(var_expl)
# Out:
# array([0.38248429, 0.61065042, 0.69323413, 0.74518846, 0.78784129,
#        0.81754989, 0.84260765, 0.86341314, 0.88216071, 0.8983799 ,
#        0.9135191 , 0.92592926, 0.93775667, 0.94732717, 0.95546598,
#        0.96157952, 0.96738599, 0.97273889, 0.97771355, 0.98175424,
#        0.98518636, 0.98783599, 0.99003515, 0.99216329, 0.99379264,
#        0.99522086, 0.99642775, 0.99711983, 0.99767457, 0.9981913 ,
#        0.99861792, 0.99894057, 0.9992012 , 0.999397  , 0.99957497,
#        0.99970624, 0.99979894, 0.99987785, 0.99993715, 0.99997297,
#        0.99999046, 0.99999297, 0.99999479, 0.9999964 , 0.99999793,
#        0.99999881, 0.99999955, 1.        , 1.        ])

# %% [markdown]
# Yep--using the first 14 PCAs will get us 94.7% of the variance explained

# %%
np.cumsum(var_expl)[13:15]
# Out:
# array([0.94732717, 0.95546598])

# %%
pd.DataFrame(pca.components_,columns=df.columns).head().T
# Out:
#                        0         1         2         3         4
# Age            -0.062581 -0.003926 -0.081212  0.110196 -0.049050
# G               0.153883 -0.021284 -0.031020  0.038759  0.224353
# MP_total        0.211988 -0.046669  0.042668 -0.002494  0.155993
# PER             0.188668  0.072272 -0.098223 -0.002461 -0.213030
# TS%             0.110295  0.072932 -0.372122 -0.016716 -0.176965
# 3PAr           -0.003510 -0.234766 -0.191744 -0.007095  0.217889
# FTr             0.016589  0.152658  0.063754  0.065637 -0.327065
# ORB%           -0.011892  0.275448  0.018064 -0.031727 -0.060485
# DRB%            0.018787  0.263241  0.017182 -0.061786  0.080345
# TRB%            0.005598  0.281886  0.016826 -0.048816  0.019755
# AST%            0.075525 -0.196551  0.105176  0.233506 -0.223042
# STL%            0.052505 -0.121047  0.097684  0.393499 -0.042934
# BLK%           -0.013926  0.216401  0.039867  0.099228  0.146624
# TOV%           -0.042666  0.027878  0.215017  0.313152 -0.184882
# USG%            0.131490 -0.097333  0.118602 -0.270822 -0.204493
# OWS             0.198272  0.006839 -0.119582  0.009696 -0.109471
# DWS             0.179872  0.071889  0.042863  0.174829  0.185533
# WS              0.213014  0.033757 -0.067721  0.077023 -0.003528
# WSp48           0.138075  0.110196 -0.257443  0.122628 -0.153194
# OBPM            0.178125 -0.107280 -0.206077  0.047284 -0.113297
# DBPM            0.044736  0.183337  0.048970  0.367803  0.241622
# BPM             0.180486  0.027165 -0.143793  0.278302  0.060561
# VORP            0.195716  0.006319 -0.045565  0.203017  0.003509
# Season          0.006290 -0.005975 -0.221127 -0.032961  0.192222
# GS              0.196086 -0.007605  0.083476  0.011857  0.156420
# MP_pergame      0.215629 -0.053536  0.065506 -0.025546  0.118617
# FG              0.218745 -0.043850  0.049644 -0.149001  0.007787
# FGA             0.209324 -0.086811  0.075148 -0.149908  0.030270
# FG%             0.067712  0.219733 -0.210526  0.017713 -0.156697
# 3P              0.078351 -0.222047 -0.159859 -0.043927  0.180763
# 3PA             0.081939 -0.228877 -0.136941 -0.035481  0.178614
# 3P%             0.047722 -0.238549 -0.107813 -0.021117  0.122100
# 2P              0.211446  0.029375  0.109585 -0.147018 -0.054500
# 2PA             0.207018  0.002925  0.150237 -0.159074 -0.046463
# 2P%             0.077787  0.164216 -0.290915  0.046343 -0.101442
# eFG%            0.079616  0.087573 -0.403417  0.003941 -0.025047
# FT              0.204969 -0.008469  0.091319 -0.089565 -0.170094
# FTA             0.204615  0.026708  0.112058 -0.078864 -0.157001
# FT%             0.073074 -0.172614 -0.119937 -0.122266 -0.083351
# ORB             0.106837  0.235851  0.064435 -0.087289  0.058358
# DRB             0.168592  0.157121  0.059767 -0.077248  0.173875
# TRB             0.153169  0.193739  0.064442 -0.084456  0.138100
# AST             0.135737 -0.166465  0.099791  0.211651 -0.141567
# STL             0.168331 -0.112266  0.095123  0.248869  0.031433
# BLK             0.079031  0.211932  0.057902  0.014288  0.181300
# TOV             0.194178 -0.068615  0.176997  0.031113 -0.087297
# PF              0.150173  0.110630  0.103415 -0.008425  0.125895
# PS/G            0.219794 -0.059951  0.040456 -0.136365 -0.015622
# Seasons_number  0.000000  0.000000 -0.000000  0.000000  0.000000

# %%
from scipy.spatial.distance import cdist, pdist, euclidean
from sklearn.cluster import KMeans
from sklearn import metrics


reduced_data = PCA(n_components=14).fit_transform(X) #transform data into the 14 PCA component-space

k_range = range(2,31) #looking amount of variance explained by 2 through 30 clusters
k_means_var = [KMeans(n_clusters=k).fit(reduced_data) for k in k_range] 

#get labels and calculate silhouette score
labels = [i.labels_ for i in k_means_var]
sil_score = [metrics.silhouette_score(reduced_data,i,metric='euclidean') for i in labels]

centroids = [i.cluster_centers_ for i in k_means_var] #get the center of each cluster
k_euclid = [cdist(reduced_data,cent,'euclidean') for cent in centroids] #calculate distance between each item and each cluster center
dist = [np.min(ke,axis=1) for ke in k_euclid] #get the distance between each item and its cluster

wcss = [sum(d**2) for d in dist] #within cluster sum of squares
tss = sum(pdist(reduced_data)**2/reduced_data.shape[0]) #total sum of squares
bss = tss-wcss #between cluster sum of squares

plt.clf()
plt.figure(figsize=(12,4)) #create cumulative proportion of variance plot
plt.subplot(1,2,1)
plt.plot(k_range, bss/tss*100,'o-')
plt.axis([0, np.max(k_range), 0, 100])
plt.xlabel('Number of Clusters')
plt.ylabel('Percentage of variance explained (%)');

plt.subplot(1,2,2) #create scree plot
plt.plot(k_range, np.transpose(sil_score)*100,'o-')
plt.axis([0, np.max(k_range), 0, 40])
plt.xlabel('Number of Clusters');
plt.ylabel('Average Silhouette Score*100');

# %%
final_fit = KMeans(n_clusters=10, random_state=42).fit(reduced_data)
df['kmeans_label'] = final_fit.labels_

# %%
df.groupby('kmeans_label').mean()['WS']
# Out:
# kmeans_label
# 0    2.234507
# 1    1.907500
# 2    7.309559
# 3    4.419776
# 4    0.996264
# 5    7.075000
# 6    4.330804
# 7    0.799375
# 8    2.791981
# 9    2.065672
# Name: WS, dtype: float64

# %%
from collections import defaultdict
playergroups = {}
for i in range(10):
    playergroups[i] = set(df[df['kmeans_label']==i].index)

# %%
import pprint
pprint.pprint(playergroups)
# Out:
# {0: {'Alec Burks',
#      'Allen Crabbe',
#      'Alonzo Gee',
#      'Anthony Morrow',
#      'Anthony Tolliver',
#      'Arron Afflalo',
#      'Ben McLemore',
#      'Brandon Rush',
#      'Brian Cook',
#      'Brian Roberts',
#      'C.J. Watson',
#      'Chase Budinger',
#      'Courtney Lee',
#      'Daequan Cook',
#      'Damien Wilkins',
#      'Daniel Gibson',
#      'Danny Green',
#      'Derrick Williams',
#      'Evan Fournier',
#      'Francisco Garcia',
#      'Gary Neal',
#      'Gordan Giricek',
#      'Hedo Turkoglu',
#      'Iman Shumpert',
#      'Isaiah Canaan',
#      'J.J. Redick',
#      'J.R. Smith',
#      'Jae Crowder',
#      'Jamario Moon',
#      'Jared Dudley',
#      'Jarvis Hayes',
#      'Jason Kapono',
#      'Jeremy Lamb',
#      'Jodie Meeks',
#      'Jordan Farmar',
#      'Keith Bogans',
#      'Kent Bazemore',
#      'Kyle Korver',
#      'Kyle Singler',
#      'Luther Head',
#      'Marco Belinelli',
#      'Marcus Morris',
#      'Matt Bonner',
#      'Matthew Dellavedova',
#      'Maurice Harkless',
#      'Mickael Pietrus',
#      'Mike Scott',
#      'Mirza Teletovic',
#      'Nick Young',
#      'Omri Casspi',
#      'Otto Porter',
#      'Pat Garrity',
#      'Patrick Beverley',
#      'Quincy Pondexter',
#      'Rasual Butler',
#      'Reggie Williams (ii)',
#      'Robert Covington',
#      'Rodney Carney',
#      'Shabazz Muhammad',
#      'Solomon Hill',
#      'Steve Novak',
#      'Terrence Ross',
#      'Tim Hardaway (ii)',
#      'Toney Douglas',
#      'Tony Snell',
#      'Travis Diener',
#      'Trey Burke',
#      'Troy Daniels',
#      'Vladimir Radmanovic',
#      'Wayne Ellington',
#      'Wesley Johnson'},
#  1: {'Adrian Griffin',
#      'Al Harrington',
#      'Al-Farouq Aminu',
#      'Alex Len',
#      'Andray Blatche',
#      'Andrew Nicholson',
#      'Anthony Randolph',
#      'Austin Croshere',
#      'Bobby Simmons',
#      'Cedric Henderson',
#      'Channing Frye',
#      'Chris Mihm',
#      'Dante Cunningham',
#      'Darius Miles',
#      'Darius Songaila',
#      'Donatas Motiejunas',
#      'Eddie Robinson',
#      'Erick Dampier',
#      'Gerald Henderson',
#      'Gerald Wallace',
#      'Glen Davis',
#      'Greg Buckner',
#      'Hakim Warrick',
#      'Ira Newble',
#      'J.J. Hickson',
#      'Jake Tsakalidis',
#      'James Johnson',
#      'Jamie Feick',
#      'Jared Jeffries',
#      'Jarron Collins',
#      'Jason Collins',
#      'Joey Graham',
#      'Johan Petro',
#      'John Wallace',
#      'Jumaine Jones',
#      'Kenny Thomas',
#      'Kevin Seraphin',
#      'Kwame Brown',
#      'Landry Fields',
#      'Lavoy Allen',
#      'Lee Nailon',
#      'Lorenzen Wright',
#      'Malik Allen',
#      'Marc Jackson',
#      'Marcus Fizer',
#      'Marreese Speights',
#      'Matt Barnes',
#      'Matt Harpring',
#      'Melvin Ely',
#      'Michael Doleac',
#      'Michael Olowokandi',
#      'Othella Harrington',
#      'Patrick Patterson',
#      'Quinton Ross',
#      'Rasho Nesterovic',
#      'Samaki Walker',
#      'Shandon Anderson',
#      'Spencer Hawes',
#      'Stanislav Medvedenko',
#      'Tariq Abdul-Wahad',
#      'Thabo Sefolosha',
#      'Tony Allen',
#      'Travis Outlaw',
#      'Trenton Hassell',
#      'Trevor Ariza',
#      'Troy Murphy',
#      'Tyler Hansbrough',
#      'Vitaly Potapenko',
#      'Yi Jianlian',
#      'Zaza Pachulia'},
#  2: {'Allen Iverson',
#      'Andre Iguodala',
#      'Andre Miller',
#      'Baron Davis',
#      'Brandon Jennings',
#      'Brandon Roy',
#      'Carmelo Anthony',
#      'Chris Paul',
#      'Damian Lillard',
#      'Deron Williams',
#      'Dwyane Wade',
#      'Gilbert Arenas',
#      'Isaiah Thomas',
#      'James Harden',
#      'Jason Terry',
#      'John Wall',
#      'Kemba Walker',
#      'Kevin Durant',
#      'Kirk Hinrich',
#      'Kobe Bryant',
#      'Kyrie Irving',
#      'LeBron James',
#      'Manu Ginobili',
#      'Paul George',
#      'Paul Pierce',
#      'Rajon Rondo',
#      'Ray Allen',
#      'Russell Westbrook',
#      'Stephen Curry',
#      'Stephon Marbury',
#      'Steve Francis',
#      'Tony Parker',
#      'Tyreke Evans',
#      'Vince Carter'},
#  3: {'Andrea Bargnani',
#      'Andres Nocioni',
#      'Ben Gordon',
#      'Bonzi Wells',
#      'Bradley Beal',
#      'CJ McCollum',
#      'Caron Butler',
#      'Chandler Parsons',
#      'Charlie Villanueva',
#      'Corey Maggette',
#      'Cuttino Mobley',
#      'Danilo Gallinari',
#      'Danny Granger',
#      'DeMar DeRozan',
#      'Derek Anderson',
#      'Desmond Mason',
#      'Draymond Green',
#      'Eric Gordon',
#      'George Hill',
#      'Gordon Hayward',
#      'Harrison Barnes',
#      'James Posey',
#      'Jason Richardson',
#      'Jimmy Butler',
#      'Joe Johnson',
#      'Josh Howard',
#      'Kawhi Leonard',
#      'Kelly Olynyk',
#      'Kentavious Caldwell-Pope',
#      'Kevin Martin',
#      'Khris Middleton',
#      'Klay Thompson',
#      'Lamar Odom',
#      'Leandro Barbosa',
#      'Marcus Thornton',
#      'Markieff Morris',
#      'Marvin Williams',
#      'Metta World Peace',
#      'Michael Beasley',
#      'Michael Redd',
#      'Mike Dunleavy',
#      'Mike Miller',
#      'Monta Ellis',
#      'Morris Peterson',
#      'Nate Robinson',
#      'Nicolas Batum',
#      'O.J. Mayo',
#      'Peja Stojakovic',
#      'Quentin Richardson',
#      'Rashard Lewis',
#      'Richard Hamilton',
#      'Ron Mercer',
#      'Ronnie Brewer',
#      'Ruben Patterson',
#      'Rudy Gay',
#      'Ryan Anderson',
#      'Ryan Gomes',
#      'Shane Battier',
#      'Tayshaun Prince',
#      'Thaddeus Young',
#      'Tim Thomas',
#      'Tobias Harris',
#      'Ty Lawson',
#      'Victor Oladipo',
#      'Wally Szczerbiak',
#      'Wesley Matthews',
#      'Wilson Chandler'},
#  4: {'A.J. Price',
#      'Alvin Williams',
#      'Anthony Carter',
#      'Anthony Johnson',
#      'Antoine Wright',
#      'Austin Daye',
#      'Austin Rivers',
#      'Avery Bradley',
#      'Beno Udrih',
#      'Bostjan Nachbar',
#      'Brian Cardinal',
#      'Brian Scalabrine',
#      'Bryce Drew',
#      'C.J. Miles',
#      'Carlos Arroyo',
#      'Cartier Martin',
#      'Chris Crawford',
#      'Chris Quinn',
#      'Cory Joseph',
#      'Dahntay Jones',
#      'Damon Jones',
#      'Dan Dickau',
#      'DeMarre Carroll',
#      'DeShawn Stevenson',
#      'Derek Fisher',
#      'Devean George',
#      'Devin Brown',
#      'Dion Glover',
#      'Donald Sloan',
#      'Dorell Wright',
#      "E'Twaun Moore",
#      'Earl Boykins',
#      'Eddie House',
#      'Eric Maynor',
#      'Fred Jones',
#      'Ian Clark',
#      'Ish Smith',
#      'J.J. Barea',
#      'Jacque Vaughn',
#      'James Jones',
#      'Jannero Pargo',
#      'Jerryd Bayless',
#      'Jimmer Fredette',
#      'John Jenkins',
#      'John Salmons',
#      'Jonathan Bender',
#      'Jordan Hamilton',
#      'Juan Dixon',
#      'Kevin Ollie',
#      'Keyon Dooling',
#      'Lou Williams',
#      'Luke Babbitt',
#      'Luke Walton',
#      'Marcus Banks',
#      'Martell Webster',
#      'Mateen Cleaves',
#      'Matt Carroll',
#      'Matt Maloney',
#      'Mike Wilks',
#      'Milt Palacio',
#      'Norris Cole',
#      'Patty Mills',
#      'Rafer Alston',
#      'Raja Bell',
#      'Randy Livingston',
#      'Reggie Bullock',
#      'Rick Brunson',
#      'Ricky Davis',
#      'Ronald Murray',
#      'Ronnie Price',
#      'Royal Ivey',
#      'Sasha Pavlovic',
#      'Sasha Vujacic',
#      'Scott Padgett',
#      'Shammond Williams',
#      'Shannon Brown',
#      'Shelvin Mack',
#      'Stephen Graham',
#      'Steve Blake',
#      'Tony Delk',
#      'Troy Hudson',
#      'Tyronn Lue',
#      'Walter McCarty',
#      'Wang Zhizhi',
#      'Will Barton',
#      'Willie Green',
#      'Xavier Henry'},
#  5: {'Al Horford',
#      "Amar'e Stoudemire",
#      'Andre Drummond',
#      'Andrei Kirilenko',
#      'Antawn Jamison',
#      'Anthony Davis',
#      'Antoine Walker',
#      'Blake Griffin',
#      'Brook Lopez',
#      'Carlos Boozer',
#      'Chris Bosh',
#      'DeMarcus Cousins',
#      'Dirk Nowitzki',
#      'Dwight Howard',
#      'Elton Brand',
#      'Emeka Okafor',
#      'Giannis Antetokounmpo',
#      'Greg Monroe',
#      'Josh Smith',
#      'Keith Van Horn',
#      'Kenyon Martin',
#      'Kevin Love',
#      'LaMarcus Aldridge',
#      'Luis Scola',
#      'Luol Deng',
#      'Marc Gasol',
#      'Pau Gasol',
#      'Richard Jefferson',
#      'Shareef Abdur-Rahim',
#      'Shawn Marion',
#      'Tim Duncan',
#      'Tracy McGrady',
#      'Yao Ming'},
#  6: {'Al Jefferson',
#      'Andrew Bogut',
#      'Andrew Bynum',
#      'Andris Biedrins',
#      'Brad Miller',
#      'Brendan Haywood',
#      'Carl Landry',
#      'Chris Kaman',
#      'Cody Zeller',
#      'Craig Smith',
#      'Danny Fortson',
#      'David Lee',
#      'David West',
#      'DeAndre Jordan',
#      'DeJuan Blair',
#      'Derrick Favors',
#      'Drew Gooden',
#      'Ed Davis',
#      'Eddy Curry',
#      'Enes Kanter',
#      'Gorgui Dieng',
#      'JaVale McGee',
#      'Jamaal Magloire',
#      'Jared Sullinger',
#      'Jason Thompson',
#      'Joakim Noah',
#      'John Henson',
#      'Jonas Valanciunas',
#      'Kenneth Faried',
#      'Keon Clark',
#      'Luc Mbah a Moute',
#      'Marcus Camby',
#      'Mason Plumlee',
#      'Mehmet Okur',
#      'Michael Kidd-Gilchrist',
#      'Nenad Krstic',
#      'Nick Collison',
#      'Nikola Pekovic',
#      'Nikola Vucevic',
#      'Paul Millsap',
#      'Raef LaFrentz',
#      'Roy Hibbert',
#      'Rudy Gobert',
#      'Serge Ibaka',
#      'Steven Adams',
#      'Stromile Swift',
#      'Taj Gibson',
#      'Terrence Jones',
#      'Tiago Splitter',
#      'Tony Battie',
#      'Tristan Thompson',
#      'Tyler Zeller',
#      'Tyrus Thomas',
#      'Tyson Chandler',
#      'Udonis Haslem',
#      'Zach Randolph'},
#  7: {'Adonal Foyle',
#      'Brandon Bass',
#      'Brian Skinner',
#      'Bruce Bowen',
#      'Bruno Sundov',
#      'Byron Mullens',
#      'Calvin Booth',
#      'Chris Andersen',
#      'Darko Milicic',
#      'DeSagana Diop',
#      'Didier Ilunga-Mbenga',
#      'Dominic McGuire',
#      'Dwayne Jones',
#      'Earl Clark',
#      'Ekpe Udoh',
#      'Hilton Armstrong',
#      'Jamal Sampson',
#      'Jason Collier',
#      'Jeff Adrien',
#      "Jermaine O'Neal",
#      'Jerome Moiso',
#      'Joel Przybilla',
#      'Josh Powell',
#      'Kris Humphries',
#      'Kyrylo Fesenko',
#      'Lance Thomas',
#      'Linton Johnson',
#      'Loren Woods',
#      "Mamadou N'Diaye",
#      'Michael Bradley',
#      'Michael Stewart',
#      'Nazr Mohammed',
#      'Nene Hilario',
#      'Primoz Brezec',
#      'Ronald Dupree',
#      'Shavlik Randolph',
#      'Thomas Robinson',
#      'Todd Fuller',
#      'Vladimir Stepania',
#      'Zendon Hamilton'},
#  8: {'Antonio Daniels',
#      'Bobby Jackson',
#      'Boris Diaw',
#      'Brandon Knight',
#      'Brevin Knight',
#      'Chauncey Billups',
#      'Chris Duhon',
#      'Chucky Atkins',
#      'Corey Brewer',
#      'D.J. Augustin',
#      'Darren Collison',
#      'Delonte West',
#      'Dennis Schroder',
#      'Devin Harris',
#      'Dion Waiters',
#      'Earl Watson',
#      'Eric Bledsoe',
#      'Erick Strickland',
#      'Evan Turner',
#      'Goran Dragic',
#      'Greivis Vasquez',
#      'Jamaal Tinsley',
#      'Jamal Crawford',
#      'Jameer Nelson',
#      'Jarrett Jack',
#      'Jason Williams',
#      'Jeff Teague',
#      'Jeremy Lin',
#      'Jose Calderon',
#      'Jrue Holiday',
#      'Kyle Lowry',
#      'Lance Stephenson',
#      'Larry Hughes',
#      'Luke Ridnour',
#      'Mario Chalmers',
#      'Marko Jaric',
#      'Marquis Daniels',
#      'Michael Carter-Williams',
#      'Michael Dickerson',
#      'Mike Bibby',
#      'Mike Conley',
#      'Mike James (i)',
#      'Mo Williams',
#      'Ramon Sessions',
#      'Randy Foye',
#      'Raymond Felton',
#      'Reggie Jackson',
#      'Ricky Rubio',
#      'Rodney Stuckey',
#      'Sebastian Telfair',
#      'Speedy Claxton',
#      'Stephen Jackson',
#      'Steve Nash'},
#  9: {'Aaron Gray',
#      'Amir Johnson',
#      'Anderson Varejao',
#      'Andre Roberson',
#      'Aron Baynes',
#      'Ben Wallace',
#      'Bismack Biyombo',
#      'Chris Wilcox',
#      'Chuck Hayes',
#      'Cole Aldrich',
#      'D.J. White',
#      'Dan Gadzuric',
#      'Dean Garrett',
#      'Dewayne Dedmon',
#      'Donnell Harvey',
#      'Eduardo Najera',
#      'Etan Thomas',
#      'Fabricio Oberto',
#      'Francisco Elson',
#      'Greg Smith',
#      'Hamed Haddadi',
#      'Hasheem Thabeet',
#      'Jahidi White',
#      'Jake Voskuhl',
#      'Jason Maxiell',
#      'Jeff Foster',
#      'Jeff Withey',
#      'Jelani McCoy',
#      'Jeremy Evans',
#      'Jerome Williams',
#      'Joel Anthony',
#      'Jon Leuer',
#      'Jordan Hill',
#      'Josh McRoberts',
#      'Kelvin Cato',
#      'Kendrick Perkins',
#      'Kosta Koufos',
#      "Kyle O'Quinn",
#      'Larry Sanders',
#      'Lawrence Funderburke',
#      'Leon Powe',
#      'Lou Amundson',
#      'Malik Rose',
#      'Marcin Gortat',
#      'Mark Blount',
#      'Mark Madsen',
#      'Meyers Leonard',
#      'Mike Muscala',
#      'Mikki Moore',
#      'Miles Plumlee',
#      'Omer Asik',
#      'Quincy Acy',
#      'Reggie Evans',
#      'Renaldo Balkman',
#      'Robert Traylor',
#      'Robin Lopez',
#      'Ronny Turiaf',
#      'Ryan Bowen',
#      'Ryan Hollins',
#      'Scot Pollard',
#      'Shelden Williams',
#      'Solomon Jones',
#      'Steven Hunter',
#      'Timofey Mozgov',
#      'Travis Knight',
#      'Trevor Booker',
#      'Zeljko Rebraca'}}

# %%
from scipy.stats import gaussian_kde
import matplotlib
plt.clf()

centroids = final_fit.cluster_centers_ #find centroids so we can plot them
colors = ['r','g','y','navy','c','m', 'lime','goldenrod','violet', 'teal'] #cluster colors
Clusters = ['C0','C1','C2','C3','C4','C5','C6', 'C7', 'C8', 'C9'] #cluster...names

numdata, numvars = reduced_data.shape #players by PCA components
fig, axes = plt.subplots(nrows=numvars, ncols=numvars, figsize=(60,60)) 
fig.subplots_adjust(hspace=0.05, wspace=0.05)

recs=[]
for col in colors: #make some patches for the legend
    recs.append(matplotlib.patches.Rectangle((0,0),1,1,fc=col))

fig.legend(recs,Clusters,8,ncol=6) #create legend with patches above

for i,ax in enumerate(axes.flat):
    # Hide all ticks and labels
    plt.setp(ax.get_yticklabels(), visible=False) #tick labels are too much with this many subplots
    plt.setp(ax.get_xticklabels(), visible=False)
    ax.grid(False) #again, too much
    #if i%5==0:ax.set_ylabel(factor_names[i/5]) #label outer y axes
    #if i>19:ax.set_xlabel(factor_names[i-20]) #label outer x axes

for i, j in zip(*np.triu_indices_from(axes, k=1)):
    for x, y in [(i,j), (j,i)]:
        #plot individual data points and cluster centers
        axes[y,x].plot(reduced_data[:, x], reduced_data[:, y], 'k.', markersize=2)
        axes[y,x].scatter(centroids[:,x], centroids[:,y],marker='x',s=169,linewidth=3,color=colors, zorder=10)

#create kernel density estimation for each PCA factor on the diagonals
for i in range(14):
    density = gaussian_kde(reduced_data[:,i])
    density.covariance_factor = lambda : .25
    density._compute_covariance()
    x = np.linspace(min(reduced_data[:,i]),max(reduced_data[:,1]))
    axes[i,i].plot(x,density(x))

# %%
df.index[0]
# Out:
# 'A.J. Price'

# %% [markdown]
# Players closest to centroids, per centroid.  These are the players that are nearest the center of each cluster.

# %%
for i in range(10):
    print('Centroid:',i, df.index[np.argmin([euclidean(x,final_fit.cluster_centers_[i]) for x in reduced_data])])
# Out:
# Centroid: 0 Chase Budinger
# Centroid: 1 Channing Frye
# Centroid: 2 Gilbert Arenas
# Centroid: 3 Mike Dunleavy
# Centroid: 4 J.J. Barea
# Centroid: 5 Chris Bosh
# Centroid: 6 Derrick Favors
# Centroid: 7 Loren Woods
# Centroid: 8 Luke Ridnour
# Centroid: 9 Timofey Mozgov

# %%
def make_dendrogram(dataframe, linkage_method, metric, color_threshold=None, fontsize=12., savefile=None):
    '''
    This function creates and plots the dendrogram created by hierarchical clustering.
    
    INPUTS: Pandas Dataframe, string, string, int, fontsize (float), savefile (string)
    
    OUTPUTS: None
    '''
    distxy = squareform(pdist(dataframe.values, metric=metric))
    Z = linkage(distxy, linkage_method)
    plt.figure(figsize=(54, 20))
    plt.title('Hierarchical Clustering Dendrogram')
    plt.xlabel('Players')
    plt.ylabel('distance')
    dendrogram(
        Z,
        leaf_rotation=90.,  # rotates the x axis labels
        leaf_font_size=fontsize,  # font size for the x axis labels
        labels = dataframe.index,
        color_threshold = color_threshold
    )
    if savefile:
        plt.savefig(savefile,bbox_inches='tight',dpi=1000)
    plt.show()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import pdist, squareform

# %%
linktype = 'complete'
metric = 'cosine'
make_dendrogram(df.iloc[:,:-2], linktype, metric, color_threshold=None, fontsize=7)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   # Remove the CWD from sys.path while we load stuff.

# %%
linktype = 'average'
metric = 'euclid'
make_dendrogram(df.iloc[:,:-2], linktype, metric, color_threshold=None, fontsize=7)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   # Remove the CWD from sys.path while we load stuff.

# %%
from sklearn.neighbors import NearestNeighbors

# %%
make_dendrogram(df.iloc[:,:-2], linktype, metric, color_threshold=None, fontsize=7, savefile='LBJ_dendrogram.png')

# %%
from sklearn.neighbors import NearestNeighbors


nbrs = NearestNeighbors(n_neighbors=6, algorithm='ball_tree').fit(X)
distances, indices = nbrs.kneighbors(X)

# %%
for i,player in enumerate(df.index.values):
    print(player, ":", list(df.index[indices[i][1:]]))
# Out:
# A.J. Price : ['Chris Quinn', 'Isaiah Canaan', 'Shelvin Mack', 'J.J. Barea', "E'Twaun Moore"]
# Aaron Gray : ['Timofey Mozgov', 'Jordan Hill', 'Kosta Koufos', 'Jake Voskuhl', 'Aron Baynes']
# Adonal Foyle : ['Chris Andersen', 'Joel Przybilla', 'Michael Stewart', 'Larry Sanders', 'Ben Wallace']
# Adrian Griffin : ['Greg Buckner', 'Damien Wilkins', 'Ryan Bowen', 'Thabo Sefolosha', 'Luke Walton']
# Al Harrington : ['Kwame Brown', 'Andray Blatche', 'Michael Doleac', 'Samaki Walker', 'Tariq Abdul-Wahad']
# Al Horford : ['Marc Gasol', 'Kenneth Faried', 'Greg Monroe', 'Carlos Boozer', 'LaMarcus Aldridge']
# Al Jefferson : ['Derrick Favors', 'Drew Gooden', 'Nikola Vucevic', 'Jason Thompson', 'Tristan Thompson']
# Al-Farouq Aminu : ['Thabo Sefolosha', 'Landry Fields', 'Luc Mbah a Moute', 'Jared Jeffries', 'Maurice Harkless']
# Alec Burks : ['Gerald Henderson', 'Jerryd Bayless', 'Alonzo Gee', 'Derrick Williams', 'Lou Williams']
# Alex Len : ['Andray Blatche', 'Spencer Hawes', 'Chris Mihm', 'Kwame Brown', 'J.J. Hickson']
# Allen Crabbe : ['Quincy Pondexter', 'Tony Snell', 'Wayne Ellington', 'Jason Kapono', 'Daniel Gibson']
# Allen Iverson : ['Russell Westbrook', 'Steve Francis', 'Vince Carter', 'Paul Pierce', 'Gilbert Arenas']
# Alonzo Gee : ['Damien Wilkins', 'Mickael Pietrus', 'Keith Bogans', 'Omri Casspi', 'Alec Burks']
# Alvin Williams : ['Bobby Jackson', 'Derek Fisher', 'Tony Delk', 'Antonio Daniels', 'Marcus Banks']
# Amar'e Stoudemire : ['Chris Bosh', 'Brook Lopez', 'Pau Gasol', 'LaMarcus Aldridge', 'Al Jefferson']
# Amir Johnson : ['Jeremy Evans', 'Jelani McCoy', 'Jeff Withey', 'Cole Aldrich', 'Josh McRoberts']
# Anderson Varejao : ['Jerome Williams', 'Dan Gadzuric', 'Trevor Booker', 'Jeff Foster', 'Chuck Hayes']
# Andray Blatche : ['James Johnson', 'Kwame Brown', 'Johan Petro', 'Kevin Seraphin', 'Travis Knight']
# Andre Drummond : ['Kenneth Faried', 'Emeka Okafor', 'Greg Monroe', 'Dwight Howard', 'Nikola Vucevic']
# Andre Iguodala : ['Paul George', 'Giannis Antetokounmpo', 'Richard Jefferson', 'Manu Ginobili', 'Rajon Rondo']
# Andre Miller : ['Deron Williams', 'Mike Bibby', 'Russell Westbrook', 'Jason Terry', 'John Wall']
# Andre Roberson : ['Maurice Harkless', 'Landry Fields', 'Solomon Hill', 'Thabo Sefolosha', 'Otto Porter']
# Andrea Bargnani : ['Wilson Chandler', 'Charlie Villanueva', 'Andres Nocioni', 'Mike Miller', 'Mike Dunleavy']
# Andrei Kirilenko : ['Tracy McGrady', 'Giannis Antetokounmpo', 'Marc Gasol', 'Josh Smith', 'Andre Iguodala']
# Andres Nocioni : ['Andrea Bargnani', 'Markieff Morris', 'Mike Dunleavy', 'Ryan Gomes', 'Charlie Villanueva']
# Andrew Bogut : ['Carlos Boozer', 'Jason Thompson', 'Kenneth Faried', 'Nikola Vucevic', 'Al Jefferson']
# Andrew Bynum : ['JaVale McGee', 'Ed Davis', 'Derrick Favors', 'John Henson', 'Tyson Chandler']
# Andrew Nicholson : ['Joey Graham', 'Mike Scott', 'Donatas Motiejunas', 'Jon Leuer', 'Austin Daye']
# Andris Biedrins : ['DeAndre Jordan', 'Ed Davis', 'Steven Adams', 'Andrew Bynum', 'Mason Plumlee']
# Antawn Jamison : ['Keith Van Horn', 'Jason Richardson', 'Shareef Abdur-Rahim', 'Antoine Walker', 'Drew Gooden']
# Anthony Carter : ['Anthony Johnson', 'Cedric Henderson', 'Bobby Jackson', 'Earl Watson', 'Milt Palacio']
# Anthony Davis : ['Pau Gasol', 'Yao Ming', 'Elton Brand', 'Chris Bosh', 'Blake Griffin']
# Anthony Johnson : ['Milt Palacio', 'Royal Ivey', 'Walter McCarty', 'Rafer Alston', 'Dahntay Jones']
# Anthony Morrow : ['Tim Hardaway (ii)', 'Marcus Thornton', 'Evan Fournier', 'Gary Neal', 'CJ McCollum']
# Anthony Randolph : ['Andray Blatche', 'Kwame Brown', 'Marreese Speights', 'J.J. Hickson', 'Stromile Swift']
# Anthony Tolliver : ['Omri Casspi', 'Marcus Morris', 'Austin Daye', 'Quincy Pondexter', 'Donatas Motiejunas']
# Antoine Walker : ['Keith Van Horn', 'Antawn Jamison', 'Jason Richardson', 'Lamar Odom', 'Rudy Gay']
# Antoine Wright : ['Dahntay Jones', 'Sasha Pavlovic', 'Raja Bell', 'Royal Ivey', 'Bostjan Nachbar']
# Antonio Daniels : ['Beno Udrih', 'Alvin Williams', 'Carlos Arroyo', 'C.J. Watson', 'Derek Fisher']
# Aron Baynes : ['Timofey Mozgov', 'Jordan Hill', 'Aaron Gray', 'Zeljko Rebraca', 'Shelden Williams']
# Arron Afflalo : ['Kyle Singler', 'Courtney Lee', 'Brandon Rush', 'Otto Porter', 'Pat Garrity']
# Austin Croshere : ['Jumaine Jones', 'Devin Brown', 'Scott Padgett', 'Devean George', 'Dion Glover']
# Austin Daye : ['Will Barton', 'Rodney Carney', 'Omri Casspi', 'Marcus Morris', 'Jeremy Lamb']
# Austin Rivers : ['Norris Cole', 'Sasha Pavlovic', 'Avery Bradley', 'Marcus Morris', "E'Twaun Moore"]
# Avery Bradley : ['Corey Brewer', 'Austin Rivers', 'Shannon Brown', 'Dion Glover', 'Willie Green']
# Baron Davis : ['Kirk Hinrich', 'Jrue Holiday', 'Jamaal Tinsley', 'Tony Parker', 'Jason Terry']
# Ben Gordon : ['O.J. Mayo', 'Cuttino Mobley', 'Klay Thompson', 'Bradley Beal', 'Ray Allen']
# Ben McLemore : ['Wesley Johnson', 'Terrence Ross', 'Evan Fournier', 'Tony Snell', 'Kyle Singler']
# Ben Wallace : ['Adonal Foyle', 'Dan Gadzuric', 'Anderson Varejao', 'Kelvin Cato', 'Chuck Hayes']
# Beno Udrih : ['J.J. Barea', 'Antonio Daniels', 'C.J. Watson', 'Shelvin Mack', 'Goran Dragic']
# Bismack Biyombo : ['Alex Len', 'Jahidi White', 'Omer Asik', 'Tyson Chandler', 'JaVale McGee']
# Blake Griffin : ['Chris Bosh', 'Elton Brand', 'Pau Gasol', 'Yao Ming', 'Anthony Davis']
# Bobby Jackson : ['Alvin Williams', 'Erick Strickland', 'Tony Delk', 'Marcus Banks', 'Dion Glover']
# Bobby Simmons : ['Matt Harpring', 'Marquis Daniels', 'Dion Glover', 'Greg Buckner', 'Alonzo Gee']
# Bonzi Wells : ['Ruben Patterson', 'Shandon Anderson', 'Tim Thomas', 'Marquis Daniels', 'Devin Harris']
# Boris Diaw : ['Darius Miles', 'Jared Jeffries', 'Delonte West', 'Kenny Thomas', 'Shandon Anderson']
# Bostjan Nachbar : ['Dahntay Jones', 'Shannon Brown', 'Antoine Wright', 'Luke Babbitt', 'Raja Bell']
# Brad Miller : ['David West', 'Mehmet Okur', 'Ruben Patterson', 'Carl Landry', 'Cody Zeller']
# Bradley Beal : ['O.J. Mayo', 'Brandon Knight', 'CJ McCollum', 'Victor Oladipo', 'Khris Middleton']
# Brandon Bass : ['Josh Powell', 'Kris Humphries', 'Todd Fuller', 'Samaki Walker', 'Primoz Brezec']
# Brandon Jennings : ['Kemba Walker', 'Victor Oladipo', 'Jason Terry', 'Raymond Felton', 'Brandon Knight']
# Brandon Knight : ['O.J. Mayo', 'Bradley Beal', 'Victor Oladipo', 'Randy Foye', 'Mike Conley']
# Brandon Roy : ['Kyrie Irving', 'Ray Allen', 'Vince Carter', 'Steve Francis', 'Dirk Nowitzki']
# Brandon Rush : ['Wesley Johnson', 'Terrence Ross', 'Arron Afflalo', 'Courtney Lee', 'Kyle Singler']
# Brendan Haywood : ['Keon Clark', 'JaVale McGee', 'Steven Adams', 'Tyson Chandler', 'Dan Gadzuric']
# Brevin Knight : ['Speedy Claxton', 'Jamaal Tinsley', 'Ricky Rubio', 'Marko Jaric', 'Jeremy Lin']
# Brian Cardinal : ['Scott Padgett', 'Chris Crawford', 'DeMarre Carroll', 'Devin Brown', 'Jason Collier']
# Brian Cook : ['Matt Bonner', 'Mike Scott', 'Rodney Carney', 'Patrick Patterson', 'Pat Garrity']
# Brian Roberts : ['Gary Neal', 'Jimmer Fredette', 'Beno Udrih', 'A.J. Price', 'Chris Quinn']
# Brian Scalabrine : ['Devin Brown', 'Walter McCarty', 'Earl Clark', 'Dahntay Jones', 'Devean George']
# Brian Skinner : ['Donnell Harvey', 'Jake Tsakalidis', 'Samaki Walker', 'Hilton Armstrong', 'Melvin Ely']
# Brook Lopez : ["Amar'e Stoudemire", 'LaMarcus Aldridge', 'Pau Gasol', 'Al Jefferson', 'Chris Bosh']
# Bruce Bowen : ['DeSagana Diop', 'Darko Milicic', 'Calvin Booth', 'Chris Andersen', 'Ekpe Udoh']
# Bruno Sundov : ['Byron Mullens', 'DeShawn Stevenson', 'Jonathan Bender', 'Vladimir Stepania', 'Ronald Dupree']
# Bryce Drew : ['Dan Dickau', 'Steve Blake', 'Jannero Pargo', 'Eric Maynor', 'Chris Quinn']
# Byron Mullens : ['Earl Clark', 'Vladimir Stepania', 'DeShawn Stevenson', 'Lance Thomas', 'Xavier Henry']
# C.J. Miles : ['Sasha Pavlovic', 'Shannon Brown', 'Cory Joseph', 'Quincy Pondexter', "E'Twaun Moore"]
# C.J. Watson : ['Damien Wilkins', 'Fred Jones', 'Beno Udrih', 'Alvin Williams', 'Marcus Banks']
# CJ McCollum : ['Marcus Thornton', 'Khris Middleton', 'O.J. Mayo', 'Evan Fournier', 'Nate Robinson']
# Calvin Booth : ['Malik Allen', 'Chris Andersen', 'Ekpe Udoh', 'Travis Knight', 'Loren Woods']
# Carl Landry : ['Nikola Pekovic', 'Craig Smith', 'Tiago Splitter', 'Brad Miller', 'Hakim Warrick']
# Carlos Arroyo : ['Alvin Williams', 'J.J. Barea', 'Beno Udrih', 'Antonio Daniels', 'Marcus Banks']
# Carlos Boozer : ['Greg Monroe', 'Kenneth Faried', 'Andrew Bogut', 'Al Jefferson', 'David Lee']
# Carmelo Anthony : ['Shareef Abdur-Rahim', 'Kevin Durant', 'Russell Westbrook', 'Vince Carter', 'Keith Van Horn']
# Caron Butler : ['Rudy Gay', 'Josh Howard', 'Rodney Stuckey', 'Richard Jefferson', 'Marvin Williams']
# Cartier Martin : ['Quincy Pondexter', 'Matt Carroll', 'Anthony Tolliver', 'Reggie Bullock', 'Bostjan Nachbar']
# Cedric Henderson : ['Tariq Abdul-Wahad', 'Walter McCarty', 'Corey Brewer', 'Quinton Ross', 'Al Harrington']
# Chandler Parsons : ['Wesley Matthews', 'Mike Miller', 'Danny Granger', 'Khris Middleton', 'Peja Stojakovic']
# Channing Frye : ['Marreese Speights', 'Michael Doleac', 'Yi Jianlian', 'Chris Mihm', 'Joey Graham']
# Charlie Villanueva : ['Wilson Chandler', 'Michael Beasley', 'Tobias Harris', 'Markieff Morris', 'Andrea Bargnani']
# Chase Budinger : ['Tim Hardaway (ii)', 'Reggie Williams (ii)', 'Jeremy Lamb', 'Omri Casspi', 'Terrence Ross']
# Chauncey Billups : ['Erick Strickland', 'Jamal Crawford', 'Randy Foye', 'D.J. Augustin', 'Mo Williams']
# Chris Andersen : ['Calvin Booth', 'Travis Knight', 'Adonal Foyle', 'Kelvin Cato', 'Ekpe Udoh']
# Chris Bosh : ['Pau Gasol', "Amar'e Stoudemire", 'Yao Ming', 'Shareef Abdur-Rahim', 'Elton Brand']
# Chris Crawford : ['Devin Brown', 'Lee Nailon', 'Dion Glover', 'Matt Carroll', 'Stanislav Medvedenko']
# Chris Duhon : ['Luther Head', 'Mario Chalmers', 'Delonte West', 'Matthew Dellavedova', 'Derek Fisher']
# Chris Kaman : ['Jason Thompson', 'Nenad Krstic', 'Kenny Thomas', 'Jamaal Magloire', 'Darius Miles']
# Chris Mihm : ['Samaki Walker', 'Kwame Brown', 'Vitaly Potapenko', 'Johan Petro', 'Jake Tsakalidis']
# Chris Paul : ['LeBron James', 'Dwyane Wade', 'Steve Francis', 'Brandon Roy', 'Paul Pierce']
# Chris Quinn : ['A.J. Price', 'Damon Jones', 'Jimmer Fredette', 'Travis Diener', "E'Twaun Moore"]
# Chris Wilcox : ['Robin Lopez', 'Othella Harrington', 'Craig Smith', 'J.J. Hickson', 'Marreese Speights']
# Chuck Hayes : ['Anderson Varejao', 'Jeff Foster', 'Trevor Booker', 'Renaldo Balkman', 'Dan Gadzuric']
# Chucky Atkins : ['Mike James (i)', 'Randy Foye', 'Greivis Vasquez', 'Gordan Giricek', 'Jamal Crawford']
# Cody Zeller : ['Luc Mbah a Moute', 'Gorgui Dieng', 'Michael Kidd-Gilchrist', 'Trevor Booker', 'Taj Gibson']
# Cole Aldrich : ['Hasheem Thabeet', 'Hamed Haddadi', 'Aaron Gray', 'Jeff Withey', 'Dewayne Dedmon']
# Corey Brewer : ['Avery Bradley', 'Iman Shumpert', 'Alonzo Gee', 'Jarvis Hayes', 'Dion Glover']
# Corey Maggette : ['Tim Thomas', 'Marvin Williams', 'Desmond Mason', 'Hakim Warrick', 'Kevin Martin']
# Cory Joseph : ['Quincy Pondexter', 'C.J. Miles', 'Shelvin Mack', "E'Twaun Moore", 'J.J. Barea']
# Courtney Lee : ['Khris Middleton', 'Jae Crowder', 'Arron Afflalo', 'Luther Head', 'Francisco Garcia']
# Craig Smith : ['Chris Wilcox', 'Hakim Warrick', 'Carl Landry', 'Tyler Zeller', 'Darius Songaila']
# Cuttino Mobley : ['Ray Allen', 'Peja Stojakovic', 'O.J. Mayo', 'Ben Gordon', 'Jason Richardson']
# D.J. Augustin : ['Randy Foye', 'Jarrett Jack', 'Trey Burke', 'Greivis Vasquez', 'Chauncey Billups']
# D.J. White : ['Jon Leuer', 'Mike Muscala', 'Quincy Acy', 'Brian Cook', 'Eddie Robinson']
# Daequan Cook : ['Wayne Ellington', 'Isaiah Canaan', 'Sasha Vujacic', 'Marco Belinelli', 'Allen Crabbe']
# Dahntay Jones : ['Raja Bell', 'Antoine Wright', 'Royal Ivey', 'Bostjan Nachbar', 'Shannon Brown']
# Damian Lillard : ['Kyrie Irving', 'Stephen Curry', 'Brandon Roy', 'Ray Allen', 'Gilbert Arenas']
# Damien Wilkins : ['C.J. Watson', 'Keith Bogans', 'Marquis Daniels', 'Juan Dixon', 'Alonzo Gee']
# Damon Jones : ['Chris Quinn', 'Travis Diener', 'A.J. Price', 'Steve Blake', 'Marco Belinelli']
# Dan Dickau : ['Bryce Drew', 'Jannero Pargo', 'Eric Maynor', 'Steve Blake', 'Chris Quinn']
# Dan Gadzuric : ['Ed Davis', 'Trevor Booker', 'Etan Thomas', 'Keon Clark', 'Tony Battie']
# Daniel Gibson : ['Allen Crabbe', 'Luther Head', 'Jodie Meeks', 'Arron Afflalo', 'Evan Fournier']
# Danilo Gallinari : ['Kevin Martin', 'Gordon Hayward', 'Khris Middleton', 'Wesley Matthews', 'Nicolas Batum']
# Danny Fortson : ['Brad Miller', 'Al Jefferson', 'Carlos Boozer', 'Nikola Pekovic', 'Jason Thompson']
# Danny Granger : ['Dirk Nowitzki', 'Josh Howard', 'Cuttino Mobley', 'Chandler Parsons', 'Peja Stojakovic']
# Danny Green : ['Reggie Williams (ii)', 'Chase Budinger', 'Omri Casspi', 'Jae Crowder', 'Daniel Gibson']
# Dante Cunningham : ['Lavoy Allen', 'Patrick Patterson', 'Trevor Booker', 'Glen Davis', 'Marreese Speights']
# Darius Miles : ['Kenny Thomas', 'Spencer Hawes', 'Kwame Brown', 'Vitaly Potapenko', 'Stromile Swift']
# Darius Songaila : ['Eddie Robinson', 'Tyler Zeller', 'Greg Buckner', 'Brian Cook', 'Lawrence Funderburke']
# Darko Milicic : ['Earl Clark', 'Vladimir Stepania', 'Michael Stewart', 'Kris Humphries', 'Loren Woods']
# Darren Collison : ['Mike Conley', 'Jarrett Jack', 'Jameer Nelson', 'Luke Ridnour', 'Jeff Teague']
# David Lee : ['Kenneth Faried', 'Carlos Boozer', 'Jonas Valanciunas', 'Mason Plumlee', 'Paul Millsap']
# David West : ['Kenny Thomas', 'Drew Gooden', 'Troy Murphy', 'Zach Randolph', 'Nenad Krstic']
# DeAndre Jordan : ['Andris Biedrins', 'Steven Adams', 'Bismack Biyombo', 'Andrew Bynum', 'Ed Davis']
# DeJuan Blair : ['Ed Davis', 'Trevor Booker', 'Derrick Favors', 'Luc Mbah a Moute', 'Cody Zeller']
# DeMar DeRozan : ['Marvin Williams', 'Richard Hamilton', 'Monta Ellis', 'Desmond Mason', 'Rodney Stuckey']
# DeMarcus Cousins : ["Amar'e Stoudemire", 'Greg Monroe', 'Kenyon Martin', 'Antoine Walker', 'Chris Bosh']
# DeMarre Carroll : ['Devin Brown', 'Brian Cardinal', 'Earl Clark', 'Quincy Pondexter', 'Lance Thomas']
# DeSagana Diop : ['Dominic McGuire', 'Joel Przybilla', 'Darko Milicic', 'Linton Johnson', 'Michael Stewart']
# DeShawn Stevenson : ['Dahntay Jones', 'Keyon Dooling', 'Anthony Johnson', 'Jonathan Bender', 'Xavier Henry']
# Dean Garrett : ['Francisco Elson', 'Mark Blount', 'Dan Gadzuric', 'Keon Clark', 'Zeljko Rebraca']
# Delonte West : ['Jeff Teague', 'Reggie Jackson', 'Mike Dunleavy', 'Francisco Garcia', 'George Hill']
# Dennis Schroder : ['Reggie Jackson', 'Mo Williams', 'Greivis Vasquez', 'Trey Burke', 'Jeff Teague']
# Derek Anderson : ['Cuttino Mobley', 'Rodney Stuckey', 'Kobe Bryant', 'Devin Harris', 'Jameer Nelson']
# Derek Fisher : ['Alvin Williams', 'John Salmons', 'Earl Watson', 'Fred Jones', 'Marcus Banks']
# Deron Williams : ['Jason Terry', 'Stephon Marbury', 'Mike Bibby', 'Andre Miller', 'Tony Parker']
# Derrick Favors : ['Al Jefferson', 'JaVale McGee', 'Jason Thompson', 'Tristan Thompson', 'Tyson Chandler']
# Derrick Williams : ['Omri Casspi', 'Tobias Harris', 'Alec Burks', 'Marcus Morris', 'Will Barton']
# Desmond Mason : ['Ryan Gomes', 'Marvin Williams', 'Hakim Warrick', 'Kenny Thomas', 'David West']
# Devean George : ['Devin Brown', 'Austin Croshere', 'Scott Padgett', 'Walter McCarty', 'Jumaine Jones']
# Devin Brown : ['Devean George', 'Brian Scalabrine', 'Chris Crawford', 'Austin Croshere', 'John Salmons']
# Devin Harris : ['Jameer Nelson', 'Jeremy Lin', 'Jeff Teague', 'George Hill', 'Kyle Lowry']
# Dewayne Dedmon : ['Timofey Mozgov', 'Aaron Gray', "Kyle O'Quinn", 'Marcin Gortat', 'Ed Davis']
# Didier Ilunga-Mbenga : ['Loren Woods', 'Kyrylo Fesenko', 'Hilton Armstrong', 'Michael Stewart', 'Earl Clark']
# Dion Glover : ['Tony Delk', 'Juan Dixon', 'Eddie House', 'Jarvis Hayes', 'Alvin Williams']
# Dion Waiters : ['Randy Foye', 'Trey Burke', 'O.J. Mayo', 'Mo Williams', 'Dennis Schroder']
# Dirk Nowitzki : ['Danny Granger', 'Richard Jefferson', 'Ray Allen', 'Paul Pierce', 'Josh Howard']
# Dominic McGuire : ['Loren Woods', 'Earl Clark', 'Michael Stewart', 'Brian Scalabrine', 'DeSagana Diop']
# Donald Sloan : ['Eric Maynor', 'J.J. Barea', 'Jannero Pargo', 'A.J. Price', 'Shelvin Mack']
# Donatas Motiejunas : ['Omri Casspi', 'Mickael Pietrus', 'Andrew Nicholson', 'Matt Barnes', 'Brian Cook']
# Donnell Harvey : ['Brian Skinner', 'Samaki Walker', 'Shelden Williams', 'Jake Tsakalidis', 'Hilton Armstrong']
# Dorell Wright : ['Shannon Brown', 'Ricky Davis', 'Randy Livingston', 'Ronnie Price', 'Dion Glover']
# Draymond Green : ['James Posey', 'Markieff Morris', 'Paul George', 'Shane Battier', 'Gorgui Dieng']
# Drew Gooden : ['Troy Murphy', 'Al Jefferson', 'David West', 'Kenny Thomas', 'Jason Thompson']
# Dwayne Jones : ['Zendon Hamilton', "Mamadou N'Diaye", 'Ryan Hollins', 'Michael Stewart', 'Loren Woods']
# Dwight Howard : ['Yao Ming', 'Elton Brand', 'Chris Bosh', 'Pau Gasol', 'Marc Gasol']
# Dwyane Wade : ['LeBron James', 'Steve Francis', 'Russell Westbrook', 'Allen Iverson', 'Vince Carter']
# E'Twaun Moore : ['Ian Clark', 'Wayne Ellington', 'Shelvin Mack', 'Quincy Pondexter', 'Ronnie Price']
# Earl Boykins : ['Troy Hudson', 'Carlos Arroyo', 'Jannero Pargo', 'Tyronn Lue', 'Tony Delk']
# Earl Clark : ['Brian Scalabrine', 'Lance Thomas', 'Dahntay Jones', 'Brandon Bass', 'Kris Humphries']
# Earl Watson : ['Derek Fisher', 'Marcus Banks', 'Alvin Williams', 'Antonio Daniels', 'Bobby Jackson']
# Ed Davis : ['Trevor Booker', 'Dan Gadzuric', 'John Henson', 'JaVale McGee', 'Andrew Bynum']
# Eddie House : ['Tony Delk', 'Juan Dixon', 'Dion Glover', 'A.J. Price', 'Willie Green']
# Eddie Robinson : ['Marquis Daniels', 'Darius Songaila', 'Shandon Anderson', 'Brian Cook', 'Greg Buckner']
# Eddy Curry : ['Nenad Krstic', 'Hakim Warrick', 'Enes Kanter', 'J.J. Hickson', 'Jason Thompson']
# Eduardo Najera : ['Greg Buckner', 'Ryan Bowen', 'Trevor Booker', 'Scot Pollard', 'Mark Madsen']
# Ekpe Udoh : ['Calvin Booth', 'Chris Andersen', 'Melvin Ely', 'James Johnson', 'Lavoy Allen']
# Elton Brand : ['Pau Gasol', 'Chris Bosh', 'Yao Ming', 'Blake Griffin', 'Anthony Davis']
# Emeka Okafor : ['Al Jefferson', 'Nikola Vucevic', 'Andrew Bogut', 'Marcus Camby', 'Roy Hibbert']
# Enes Kanter : ['J.J. Hickson', 'Marreese Speights', 'Eddy Curry', 'Zach Randolph', 'Jason Thompson']
# Eric Bledsoe : ['Jeremy Lin', 'Jeff Teague', 'Goran Dragic', 'Tony Allen', 'Kyle Lowry']
# Eric Gordon : ['Isaiah Thomas', 'Cuttino Mobley', 'Brandon Knight', 'Bradley Beal', 'O.J. Mayo']
# Eric Maynor : ['Shelvin Mack', 'J.J. Barea', 'Bryce Drew', 'Donald Sloan', 'Dan Dickau']
# Erick Dampier : ['Chris Mihm', 'Kwame Brown', 'Lorenzen Wright', 'Yi Jianlian', 'Rasho Nesterovic']
# Erick Strickland : ['Bobby Jackson', 'Stephen Jackson', 'Dion Glover', 'Juan Dixon', 'Chauncey Billups']
# Etan Thomas : ['Jahidi White', 'Jordan Hill', 'Jason Maxiell', 'Jake Tsakalidis', 'Timofey Mozgov']
# Evan Fournier : ['J.R. Smith', 'Tim Hardaway (ii)', 'Leandro Barbosa', 'CJ McCollum', 'Chase Budinger']
# Evan Turner : ['Markieff Morris', 'Michael Beasley', 'Wilson Chandler', 'Ryan Gomes', 'Gerald Henderson']
# Fabricio Oberto : ['Francisco Elson', 'Aron Baynes', 'Zeljko Rebraca', 'Dewayne Dedmon', 'Aaron Gray']
# Francisco Elson : ['Mark Blount', 'Travis Knight', 'Timofey Mozgov', 'Dean Garrett', 'Darius Songaila']
# Francisco Garcia : ['Courtney Lee', 'Mickael Pietrus', 'Delonte West', 'George Hill', 'Damien Wilkins']
# Fred Jones : ['John Salmons', 'C.J. Watson', 'Derek Fisher', 'Marcus Banks', 'Alvin Williams']
# Gary Neal : ['Brian Roberts', 'Tim Hardaway (ii)', 'Mirza Teletovic', 'Anthony Morrow', 'Chase Budinger']
# George Hill : ['Courtney Lee', 'Gordon Hayward', 'Delonte West', 'Francisco Garcia', 'Arron Afflalo']
# Gerald Henderson : ['Alec Burks', 'Jarvis Hayes', 'Dion Glover', 'Alonzo Gee', 'Derrick Williams']
# Gerald Wallace : ['Travis Outlaw', 'Kris Humphries', 'Andray Blatche', 'Trevor Ariza', 'Al Harrington']
# Giannis Antetokounmpo : ['Richard Jefferson', 'Marc Gasol', 'Andre Iguodala', 'Luol Deng', 'Greg Monroe']
# Gilbert Arenas : ['Ray Allen', 'Jason Terry', 'Kyrie Irving', 'Stephon Marbury', 'Stephen Curry']
# Glen Davis : ['Luc Mbah a Moute', 'Kwame Brown', 'Channing Frye', 'Tyler Hansbrough', 'Dante Cunningham']
# Goran Dragic : ['Beno Udrih', 'Reggie Jackson', 'Delonte West', 'Jeff Teague', 'Greivis Vasquez']
# Gordan Giricek : ['Nick Young', 'Juan Dixon', 'Randy Foye', 'Jarvis Hayes', 'Gerald Henderson']
# Gordon Hayward : ['Jarrett Jack', 'George Hill', 'Khris Middleton', 'Mike Conley', 'Delonte West']
# Gorgui Dieng : ['Cody Zeller', 'Joakim Noah', 'Paul Millsap', 'Mason Plumlee', 'Luc Mbah a Moute']
# Greg Buckner : ['Eduardo Najera', 'Matt Barnes', 'Ryan Bowen', 'Bobby Simmons', 'Darius Songaila']
# Greg Monroe : ['Kenneth Faried', 'Carlos Boozer', 'Andrew Bogut', 'Nikola Vucevic', 'LaMarcus Aldridge']
# Greg Smith : ['Jelani McCoy', 'Jeremy Evans', 'Josh McRoberts', 'Dewayne Dedmon', 'Steven Hunter']
# Greivis Vasquez : ['Goran Dragic', 'Reggie Jackson', 'Jarrett Jack', 'Randy Foye', 'Dennis Schroder']
# Hakim Warrick : ['Tyler Zeller', 'Craig Smith', 'Othella Harrington', 'J.J. Hickson', 'John Wallace']
# Hamed Haddadi : ['Cole Aldrich', 'Kendrick Perkins', 'Aaron Gray', 'Kosta Koufos', 'Jeff Adrien']
# Harrison Barnes : ['Otto Porter', 'Mike Dunleavy', 'Ryan Gomes', 'Arron Afflalo', 'Courtney Lee']
# Hasheem Thabeet : ['Ryan Hollins', 'Solomon Jones', 'Cole Aldrich', 'Hilton Armstrong', 'Joel Anthony']
# Hedo Turkoglu : ['George Hill', 'Mike Dunleavy', 'Fred Jones', 'Vladimir Radmanovic', 'Luther Head']
# Hilton Armstrong : ['Solomon Jones', 'Donnell Harvey', 'Josh Powell', 'Brian Skinner', 'Kyrylo Fesenko']
# Ian Clark : ["E'Twaun Moore", 'Ronnie Price', 'Jimmer Fredette', 'Chris Quinn', 'Quincy Pondexter']
# Iman Shumpert : ['Corey Brewer', 'Keith Bogans', 'Delonte West', 'Alonzo Gee', 'Stephen Jackson']
# Ira Newble : ['Matt Barnes', 'Devin Brown', 'Lee Nailon', 'Damien Wilkins', 'Mark Madsen']
# Isaiah Canaan : ['A.J. Price', 'Marco Belinelli', 'Daequan Cook', 'Chris Quinn', 'Jimmer Fredette']
# Isaiah Thomas : ['Ty Lawson', 'Eric Gordon', 'Jason Terry', 'Nate Robinson', 'James Harden']
# Ish Smith : ['Rafer Alston', 'Anthony Johnson', 'Donald Sloan', 'Mike Wilks', 'Ronnie Price']
# J.J. Barea : ['Shelvin Mack', 'Beno Udrih', 'A.J. Price', 'Jimmer Fredette', 'Eric Maynor']
# J.J. Hickson : ['Marreese Speights', 'Tyler Zeller', 'Chris Wilcox', 'Michael Kidd-Gilchrist', 'Kwame Brown']
# J.J. Redick : ['Jason Kapono', 'Travis Diener', 'Allen Crabbe', 'Marco Belinelli', 'Jodie Meeks']
# J.R. Smith : ['Evan Fournier', 'Tim Hardaway (ii)', 'Nate Robinson', 'Leandro Barbosa', 'Chase Budinger']
# JaVale McGee : ['John Henson', 'Andrew Bynum', 'Derrick Favors', 'Ed Davis', 'Keon Clark']
# Jacque Vaughn : ['Milt Palacio', 'Dan Dickau', 'Keyon Dooling', 'Carlos Arroyo', 'Eric Maynor']
# Jae Crowder : ['Otto Porter', 'Courtney Lee', 'Jared Dudley', 'Arron Afflalo', 'Francisco Garcia']
# Jahidi White : ['Etan Thomas', 'Jake Tsakalidis', 'Omer Asik', 'Bismack Biyombo', 'Othella Harrington']
# Jake Tsakalidis : ['Samaki Walker', 'Brian Skinner', 'Melvin Ely', 'Donnell Harvey', 'Johan Petro']
# Jake Voskuhl : ['Timofey Mozgov', 'Aaron Gray', 'Jake Tsakalidis', 'Donnell Harvey', 'Ryan Hollins']
# Jamaal Magloire : ['Tyson Chandler', 'Derrick Favors', 'Brendan Haywood', 'Keon Clark', 'Jason Thompson']
# Jamaal Tinsley : ['Marko Jaric', 'Baron Davis', 'Ricky Rubio', 'Brevin Knight', 'Jeremy Lin']
# Jamal Crawford : ['Mo Williams', 'Trey Burke', 'Chauncey Billups', 'Randy Foye', 'Delonte West']
# Jamal Sampson : ['Shavlik Randolph', "Jermaine O'Neal", 'Jeff Adrien', 'Michael Stewart', 'Kris Humphries']
# Jamario Moon : ['Jae Crowder', 'Matt Bonner', 'Arron Afflalo', 'Otto Porter', 'Brandon Rush']
# Jameer Nelson : ['Darren Collison', 'Mike Conley', 'Devin Harris', 'Delonte West', 'Jarrett Jack']
# James Harden : ['Isaiah Thomas', 'Kevin Martin', 'Danny Granger', 'Gilbert Arenas', 'Manu Ginobili']
# James Johnson : ['Andray Blatche', 'Thabo Sefolosha', 'Matt Barnes', 'Al-Farouq Aminu', 'Ekpe Udoh']
# James Jones : ['Sasha Vujacic', 'Rasual Butler', 'Daequan Cook', 'Devean George', 'Wayne Ellington']
# James Posey : ['Mike Dunleavy', 'Morris Peterson', 'Shane Battier', 'Stephen Jackson', 'Vladimir Radmanovic']
# Jamie Feick : ['Lorenzen Wright', 'Jared Jeffries', 'Jeff Foster', 'Travis Knight', 'Kwame Brown']
# Jannero Pargo : ['Dan Dickau', 'Bryce Drew', 'Eric Maynor', 'Rafer Alston', 'Shannon Brown']
# Jared Dudley : ['Jae Crowder', 'Arron Afflalo', 'Otto Porter', 'George Hill', 'Matt Bonner']
# Jared Jeffries : ['Matt Barnes', 'Kwame Brown', 'Al-Farouq Aminu', 'Luke Walton', 'Thabo Sefolosha']
# Jared Sullinger : ['Markieff Morris', 'Charlie Villanueva', 'David West', 'Nikola Vucevic', 'Drew Gooden']
# Jarrett Jack : ['Darren Collison', 'Gordon Hayward', 'Luke Ridnour', 'Mike Conley', 'Jameer Nelson']
# Jarron Collins : ['Jake Voskuhl', 'Jake Tsakalidis', 'Melvin Ely', 'Glen Davis', 'Mark Madsen']
# Jarvis Hayes : ['Keith Bogans', 'Dion Glover', 'Juan Dixon', 'Gordan Giricek', 'Marcus Morris']
# Jason Collier : ['Primoz Brezec', 'Malik Allen', 'Lee Nailon', 'Josh Powell', 'Brandon Bass']
# Jason Collins : ['Luc Mbah a Moute', 'Glen Davis', 'Jared Jeffries', 'Mark Blount', 'Kenny Thomas']
# Jason Kapono : ['Wayne Ellington', 'Marco Belinelli', 'Rasual Butler', 'Pat Garrity', 'Matt Carroll']
# Jason Maxiell : ['Etan Thomas', 'Robin Lopez', 'Steven Hunter', 'Lou Amundson', 'Donnell Harvey']
# Jason Richardson : ['Rudy Gay', 'Cuttino Mobley', 'Ray Allen', 'Tyreke Evans', 'O.J. Mayo']
# Jason Terry : ['Ray Allen', 'Mike Bibby', 'Gilbert Arenas', 'Cuttino Mobley', 'Brandon Jennings']
# Jason Thompson : ['Tristan Thompson', 'Nick Collison', 'Nenad Krstic', 'Derrick Favors', 'Drew Gooden']
# Jason Williams : ['Raymond Felton', 'Jamaal Tinsley', 'Brandon Knight', 'Marko Jaric', 'Jamal Crawford']
# Jeff Adrien : ['Shelden Williams', 'Jordan Hill', 'Josh Powell', 'Primoz Brezec', 'Lou Amundson']
# Jeff Foster : ['Jerome Williams', 'Anderson Varejao', 'Malik Rose', 'Eduardo Najera', 'Robert Traylor']
# Jeff Teague : ['Reggie Jackson', 'Delonte West', 'Luke Ridnour', 'Mike Conley', 'Goran Dragic']
# Jeff Withey : ['Jeremy Evans', 'Ronny Turiaf', 'Mike Muscala', 'Cole Aldrich', 'Robin Lopez']
# Jelani McCoy : ['Greg Smith', 'Steven Hunter', 'Ryan Hollins', 'Josh McRoberts', 'Michael Bradley']
# Jeremy Evans : ['Jeff Withey', 'Greg Smith', 'Josh McRoberts', 'Amir Johnson', 'Jelani McCoy']
# Jeremy Lamb : ['Chase Budinger', 'Rodney Carney', 'Austin Daye', 'Will Barton', 'Allen Crabbe']
# Jeremy Lin : ['Eric Bledsoe', 'Devin Harris', 'Jeff Teague', 'Speedy Claxton', 'Kyle Lowry']
# Jermaine O'Neal : ['Kosta Koufos', 'Samaki Walker', 'Kris Humphries', 'Jake Tsakalidis', 'Donnell Harvey']
# Jerome Moiso : ['Kyrylo Fesenko', 'Vladimir Stepania', 'Hilton Armstrong', 'Loren Woods', 'Michael Bradley']
# Jerome Williams : ['Jeff Foster', 'Anderson Varejao', 'Scot Pollard', 'Malik Rose', 'Eduardo Najera']
# Jerryd Bayless : ['Alec Burks', 'Lou Williams', 'Beno Udrih', 'Goran Dragic', 'J.J. Barea']
# Jimmer Fredette : ['Marco Belinelli', 'J.J. Barea', 'Chris Quinn', 'Ian Clark', 'A.J. Price']
# Jimmy Butler : ['George Hill', 'Kevin Martin', 'Ronnie Brewer', 'Shane Battier', 'Tayshaun Prince']
# Joakim Noah : ['Paul Millsap', 'Kenneth Faried', 'Mason Plumlee', 'Derrick Favors', 'Andrew Bogut']
# Jodie Meeks : ['Terrence Ross', 'Tony Snell', 'Allen Crabbe', 'Tim Hardaway (ii)', 'Chase Budinger']
# Joe Johnson : ['Mike Dunleavy', 'Mike Miller', 'O.J. Mayo', 'Morris Peterson', 'Mike Conley']
# Joel Anthony : ['Ronny Turiaf', 'Hasheem Thabeet', 'Mark Blount', 'Ekpe Udoh', 'Hilton Armstrong']
# Joel Przybilla : ['Michael Stewart', 'Adonal Foyle', 'Loren Woods', 'Dominic McGuire', 'DeSagana Diop']
# Joey Graham : ['Andrew Nicholson', 'Channing Frye', 'Brian Cook', 'Lee Nailon', 'Darius Songaila']
# Johan Petro : ['Kevin Seraphin', 'Chris Mihm', 'Jake Tsakalidis', 'Samaki Walker', 'Michael Doleac']
# John Henson : ['JaVale McGee', 'Ed Davis', 'Andrew Bynum', 'Dan Gadzuric', 'Taj Gibson']
# John Jenkins : ['Ian Clark', 'Stephen Graham', 'Quincy Pondexter', 'Reggie Bullock', 'Jimmer Fredette']
# John Salmons : ['Fred Jones', 'Luke Walton', 'Sasha Pavlovic', 'Derek Fisher', 'Marcus Banks']
# John Wall : ['Russell Westbrook', 'Tyreke Evans', 'Andre Miller', 'Kemba Walker', 'Stephon Marbury']
# John Wallace : ['Vitaly Potapenko', 'Hakim Warrick', 'Melvin Ely', 'Channing Frye', 'Lee Nailon']
# Jon Leuer : ['Andrew Nicholson', 'Mike Muscala', 'Brian Cook', 'Quincy Acy', 'Mike Scott']
# Jonas Valanciunas : ['Kenneth Faried', 'David Lee', 'Al Jefferson', 'Derrick Favors', 'Joakim Noah']
# Jonathan Bender : ['Bostjan Nachbar', 'Dahntay Jones', 'DeShawn Stevenson', 'Earl Clark', 'Xavier Henry']
# Jordan Farmar : ['Beno Udrih', 'Luther Head', 'Shelvin Mack', 'Sasha Pavlovic', 'Goran Dragic']
# Jordan Hamilton : ['Luke Babbitt', 'Cartier Martin', 'Reggie Bullock', 'Quincy Pondexter', 'Jon Leuer']
# Jordan Hill : ['Timofey Mozgov', 'Aaron Gray', 'Kosta Koufos', 'Etan Thomas', 'Miles Plumlee']
# Jose Calderon : ['Ty Lawson', 'Darren Collison', 'Jameer Nelson', 'Jarrett Jack', 'Devin Harris']
# Josh Howard : ['Caron Butler', 'Mehmet Okur', 'Luol Deng', 'Shane Battier', 'Danny Granger']
# Josh McRoberts : ['Aaron Gray', 'Jon Leuer', 'Quincy Acy', 'Kosta Koufos', 'Renaldo Balkman']
# Josh Powell : ['Brandon Bass', 'Shelden Williams', 'Todd Fuller', 'Melvin Ely', 'Primoz Brezec']
# Josh Smith : ['Kenyon Martin', 'Giannis Antetokounmpo', 'Marcus Camby', 'Roy Hibbert', 'Lamar Odom']
# Jrue Holiday : ['Raymond Felton', 'Mike Conley', 'Victor Oladipo', 'Mike Bibby', 'Jameer Nelson']
# Juan Dixon : ['Tony Delk', 'Eddie House', 'Dion Glover', 'Toney Douglas', 'Gordan Giricek']
# Jumaine Jones : ['Austin Croshere', 'Omri Casspi', 'Devean George', 'Scott Padgett', 'Austin Daye']
# Kawhi Leonard : ['Paul George', 'Josh Howard', 'Shane Battier', 'Chandler Parsons', 'Nicolas Batum']
# Keith Bogans : ['Jarvis Hayes', 'Damien Wilkins', 'Omri Casspi', 'John Salmons', 'Marcus Morris']
# Keith Van Horn : ['Antawn Jamison', 'Antoine Walker', 'Rudy Gay', 'Shareef Abdur-Rahim', 'Richard Jefferson']
# Kelly Olynyk : ['Markieff Morris', 'Francisco Garcia', 'Jared Dudley', 'Patrick Patterson', 'George Hill']
# Kelvin Cato : ['Ronny Turiaf', 'Robert Traylor', 'Travis Knight', 'Keon Clark', 'Scot Pollard']
# Kemba Walker : ['Brandon Jennings', 'Victor Oladipo', 'Raymond Felton', 'Brandon Knight', 'Tyreke Evans']
# Kendrick Perkins : ['Aaron Gray', 'Kosta Koufos', 'Timofey Mozgov', 'Jake Tsakalidis', 'Donnell Harvey']
# Kenneth Faried : ['Jonas Valanciunas', 'Greg Monroe', 'David Lee', 'Joakim Noah', 'Carlos Boozer']
# Kenny Thomas : ['David West', 'Troy Murphy', 'Drew Gooden', 'Darius Miles', 'Lorenzen Wright']
# Kent Bazemore : ['Will Barton', 'Omri Casspi', 'John Salmons', 'Thabo Sefolosha', 'Jordan Farmar']
# Kentavious Caldwell-Pope : ['Courtney Lee', 'Khris Middleton', 'Terrence Ross', 'Morris Peterson', 'Harrison Barnes']
# Kenyon Martin : ['Josh Smith', 'Richard Jefferson', 'Luol Deng', 'Caron Butler', 'Josh Howard']
# Keon Clark : ['Tony Battie', 'Stromile Swift', 'Taj Gibson', 'Lorenzen Wright', 'Dan Gadzuric']
# Kevin Durant : ['Carmelo Anthony', 'Paul Pierce', 'Vince Carter', 'Brandon Roy', 'Dirk Nowitzki']
# Kevin Love : ['Chris Bosh', 'Carlos Boozer', "Amar'e Stoudemire", 'Greg Monroe', 'Dirk Nowitzki']
# Kevin Martin : ['Danilo Gallinari', 'Gordon Hayward', 'Peja Stojakovic', 'Corey Maggette', 'Cuttino Mobley']
# Kevin Ollie : ['Mike Wilks', 'Anthony Johnson', 'Dahntay Jones', 'Jacque Vaughn', 'Rick Brunson']
# Kevin Seraphin : ['Johan Petro', 'Melvin Ely', 'Andray Blatche', 'Josh Powell', 'Timofey Mozgov']
# Keyon Dooling : ['Shannon Brown', 'J.J. Barea', 'Bryce Drew', 'Tyronn Lue', 'Eddie House']
# Khris Middleton : ['Wesley Matthews', 'CJ McCollum', 'O.J. Mayo', 'Courtney Lee', 'Gordon Hayward']
# Kirk Hinrich : ['Jason Terry', 'Baron Davis', 'Brandon Jennings', 'Tony Parker', 'Raymond Felton']
# Klay Thompson : ['O.J. Mayo', 'Bradley Beal', 'Wesley Matthews', 'Ben Gordon', 'CJ McCollum']
# Kobe Bryant : ['Richard Jefferson', 'Derek Anderson', 'Tracy McGrady', 'Cuttino Mobley', 'Tyreke Evans']
# Kosta Koufos : ['Jordan Hill', 'Aaron Gray', "Jermaine O'Neal", 'Donnell Harvey', 'Solomon Jones']
# Kris Humphries : ['Gerald Wallace', 'Brandon Bass', 'Nazr Mohammed', "Jermaine O'Neal", 'Thomas Robinson']
# Kwame Brown : ['Zaza Pachulia', 'Chris Mihm', 'Vitaly Potapenko', 'Samaki Walker', 'Al Harrington']
# Kyle Korver : ['Vladimir Radmanovic', 'Terrence Ross', 'Luther Head', 'Morris Peterson', 'Courtney Lee']
# Kyle Lowry : ['Devin Harris', 'Jeremy Lin', 'Speedy Claxton', 'Eric Bledsoe', 'Goran Dragic']
# Kyle O'Quinn : ['Timofey Mozgov', 'Jordan Hill', 'Lavoy Allen', 'Marcin Gortat', 'Aaron Gray']
# Kyle Singler : ['Wesley Johnson', 'Tony Snell', 'Arron Afflalo', 'Keith Bogans', 'Brandon Rush']
# Kyrie Irving : ['Stephen Curry', 'Gilbert Arenas', 'Brandon Roy', 'Damian Lillard', 'Ray Allen']
# Kyrylo Fesenko : ['Lou Amundson', 'Hilton Armstrong', 'Jerome Moiso', 'Michael Bradley', 'Kosta Koufos']
# LaMarcus Aldridge : ['Brook Lopez', 'Luol Deng', 'Josh Howard', 'Drew Gooden', 'Al Jefferson']
# Lamar Odom : ['Tyreke Evans', 'Keith Van Horn', 'Richard Jefferson', 'Rudy Gay', 'Antoine Walker']
# Lance Stephenson : ['Thabo Sefolosha', 'Landry Fields', 'Avery Bradley', 'Reggie Jackson', 'Luke Walton']
# Lance Thomas : ['Earl Clark', 'Dahntay Jones', 'Josh Powell', 'Xavier Henry', 'DeMarre Carroll']
# Landry Fields : ['Thabo Sefolosha', 'Maurice Harkless', 'Matt Barnes', 'Omri Casspi', 'Solomon Hill']
# Larry Hughes : ['Rodney Stuckey', 'Monta Ellis', 'Caron Butler', 'Ron Mercer', 'Mo Williams']
# Larry Sanders : ['Chris Andersen', 'Keon Clark', 'Taj Gibson', 'Adonal Foyle', 'Tony Battie']
# Lavoy Allen : ['Miles Plumlee', 'Dante Cunningham', 'Jordan Hill', 'Kevin Seraphin', "Kyle O'Quinn"]
# Lawrence Funderburke : ['Darius Songaila', 'Zeljko Rebraca', 'Eduardo Najera', 'Lee Nailon', 'Eddie Robinson']
# LeBron James : ['Dwyane Wade', 'Kevin Durant', 'Vince Carter', 'Steve Francis', 'Chris Paul']
# Leandro Barbosa : ['Evan Fournier', 'Nate Robinson', 'Delonte West', 'J.R. Smith', 'CJ McCollum']
# Lee Nailon : ['Stanislav Medvedenko', 'Chris Crawford', 'Devin Brown', 'Ira Newble', 'Joey Graham']
# Leon Powe : ['Etan Thomas', 'Shelden Williams', 'Jason Maxiell', 'Jordan Hill', 'Robin Lopez']
# Linton Johnson : ['Dominic McGuire', 'Vladimir Stepania', 'DeSagana Diop', 'Brian Scalabrine', 'Ish Smith']
# Loren Woods : ['Michael Stewart', 'Josh Powell', 'Hilton Armstrong', 'Earl Clark', 'Brian Skinner']
# Lorenzen Wright : ['Tony Battie', 'Kwame Brown', 'Chris Mihm', 'Keon Clark', 'Kenny Thomas']
# Lou Amundson : ['Kyrylo Fesenko', 'Hilton Armstrong', 'Solomon Jones', 'Jason Maxiell', 'Aaron Gray']
# Lou Williams : ['Jerryd Bayless', 'Dion Glover', 'Beno Udrih', 'Marcus Banks', 'Carlos Arroyo']
# Luc Mbah a Moute : ['Cody Zeller', 'Glen Davis', 'Trevor Booker', 'Al-Farouq Aminu', 'Kenny Thomas']
# Luis Scola : ['Udonis Haslem', 'Carlos Boozer', 'LaMarcus Aldridge', 'Kenneth Faried', 'Nikola Vucevic']
# Luke Babbitt : ['Bostjan Nachbar', 'Cartier Martin', 'Reggie Bullock', 'Austin Daye', 'Daequan Cook']
# Luke Ridnour : ['Mo Williams', 'Mike Conley', 'Jarrett Jack', 'Jeff Teague', 'Darren Collison']
# Luke Walton : ['Matt Barnes', 'John Salmons', 'Fred Jones', 'Thabo Sefolosha', 'Landry Fields']
# Luol Deng : ['Richard Jefferson', 'LaMarcus Aldridge', 'Josh Howard', 'Caron Butler', 'Drew Gooden']
# Luther Head : ['Courtney Lee', 'Toney Douglas', 'Chris Duhon', 'Fred Jones', 'Jordan Farmar']
# Malik Allen : ['Michael Doleac', 'Calvin Booth', 'Melvin Ely', 'Jason Collier', 'Rasho Nesterovic']
# Malik Rose : ['Robert Traylor', 'Travis Knight', 'Jeff Foster', 'Trevor Ariza', 'Donnell Harvey']
# Mamadou N'Diaye : ['Jason Collier', 'Jeff Adrien', 'Primoz Brezec', 'Wang Zhizhi', 'Zendon Hamilton']
# Manu Ginobili : ['Andre Iguodala', 'James Harden', 'Paul George', 'Derek Anderson', 'Shane Battier']
# Marc Gasol : ['Al Horford', 'Kenneth Faried', 'Joakim Noah', 'Giannis Antetokounmpo', 'Greg Monroe']
# Marc Jackson : ['Tyler Hansbrough', 'Lee Nailon', 'Channing Frye', 'Marcus Fizer', 'Ira Newble']
# Marcin Gortat : ['Trevor Booker', 'Ed Davis', "Kyle O'Quinn", 'Dewayne Dedmon', 'Jordan Hill']
# Marco Belinelli : ['Wayne Ellington', 'Jason Kapono', 'Jimmer Fredette', 'Isaiah Canaan', 'Matt Carroll']
# Marcus Banks : ['Alvin Williams', 'Earl Watson', 'John Salmons', 'C.J. Watson', 'Derek Fisher']
# Marcus Camby : ['Stromile Swift', 'Roy Hibbert', 'Keon Clark', 'Tony Battie', 'Raef LaFrentz']
# Marcus Fizer : ['John Wallace', 'Channing Frye', 'Yi Jianlian', 'Marc Jackson', 'Chris Mihm']
# Marcus Morris : ['Omri Casspi', 'Rodney Carney', 'Will Barton', 'Austin Daye', 'Keith Bogans']
# Marcus Thornton : ['CJ McCollum', 'Nate Robinson', 'Anthony Morrow', 'Khris Middleton', 'O.J. Mayo']
# Mario Chalmers : ['Chris Duhon', 'Delonte West', 'Patrick Beverley', 'Iman Shumpert', 'Marko Jaric']
# Mark Blount : ['Francisco Elson', 'Travis Knight', 'Timofey Mozgov', 'Keon Clark', 'Jake Voskuhl']
# Mark Madsen : ['Ira Newble', 'Eduardo Najera', 'Matt Barnes', 'Melvin Ely', 'Shelden Williams']
# Markieff Morris : ['Charlie Villanueva', 'Wilson Chandler', 'Mike Dunleavy', 'Ryan Gomes', 'Jared Sullinger']
# Marko Jaric : ['Stephen Jackson', 'Erick Strickland', 'Bobby Jackson', 'Mike James (i)', 'Earl Watson']
# Marquis Daniels : ['Eddie Robinson', 'Damien Wilkins', 'Shandon Anderson', 'Bobby Simmons', 'Tony Allen']
# Marreese Speights : ['Channing Frye', 'Tyler Zeller', 'J.J. Hickson', 'Jordan Hill', 'Chris Wilcox']
# Martell Webster : ['Bostjan Nachbar', 'Luke Babbitt', 'James Jones', 'Antoine Wright', 'Daequan Cook']
# Marvin Williams : ['Desmond Mason', 'Ryan Gomes', 'DeMar DeRozan', 'Corey Maggette', 'Tobias Harris']
# Mason Plumlee : ['Steven Adams', 'Tiago Splitter', 'Kenneth Faried', 'Paul Millsap', 'Joakim Noah']
# Mateen Cleaves : ['Rick Brunson', 'Rafer Alston', 'Anthony Johnson', 'Jannero Pargo', 'Ish Smith']
# Matt Barnes : ['Luke Walton', 'Landry Fields', 'Greg Buckner', 'Ira Newble', 'John Salmons']
# Matt Bonner : ['Brian Cook', 'Mike Scott', 'Arron Afflalo', 'Jared Dudley', 'Pat Garrity']
# Matt Carroll : ['Jason Kapono', 'Marco Belinelli', 'Dion Glover', 'Chris Crawford', 'Wayne Ellington']
# Matt Harpring : ['Bobby Simmons', 'Alonzo Gee', 'Hedo Turkoglu', 'Adrian Griffin', 'Erick Strickland']
# Matt Maloney : ['Steve Blake', 'Bryce Drew', 'Dan Dickau', 'Damon Jones', 'A.J. Price']
# Matthew Dellavedova : ['Steve Blake', 'Chris Duhon', 'Norris Cole', 'Eric Maynor', 'Greivis Vasquez']
# Maurice Harkless : ['Landry Fields', 'Omri Casspi', 'Otto Porter', 'Thabo Sefolosha', 'Andre Roberson']
# Mehmet Okur : ['Josh Howard', 'David West', 'Drew Gooden', 'Brad Miller', 'Jared Sullinger']
# Melvin Ely : ['Jake Tsakalidis', 'Josh Powell', 'Kevin Seraphin', 'Brian Skinner', 'Samaki Walker']
# Metta World Peace : ['Caron Butler', 'Larry Hughes', 'Baron Davis', 'Victor Oladipo', 'James Posey']
# Meyers Leonard : ['Quincy Acy', 'Mike Muscala', 'Donatas Motiejunas', 'Brian Cook', 'Andrew Nicholson']
# Michael Beasley : ['Charlie Villanueva', 'Wilson Chandler', 'Tobias Harris', 'Markieff Morris', 'Rudy Gay']
# Michael Bradley : ['Kyrylo Fesenko', 'Kosta Koufos', 'Lou Amundson', 'Brian Skinner', 'Solomon Jones']
# Michael Carter-Williams : ['Larry Hughes', 'Raymond Felton', 'Victor Oladipo', 'Evan Turner', 'Eric Bledsoe']
# Michael Dickerson : ['Randy Foye', 'Gordan Giricek', 'Chauncey Billups', 'O.J. Mayo', 'Morris Peterson']
# Michael Doleac : ['Channing Frye', 'Malik Allen', 'Rasho Nesterovic', 'Chris Mihm', 'Johan Petro']
# Michael Kidd-Gilchrist : ['Tobias Harris', 'J.J. Hickson', 'Cody Zeller', 'David West', 'Terrence Jones']
# Michael Olowokandi : ['Chris Kaman', 'Erick Dampier', 'Chris Mihm', 'Vitaly Potapenko', 'Spencer Hawes']
# Michael Redd : ['Quentin Richardson', 'Marcus Thornton', 'Nate Robinson', 'Tim Thomas', 'Rashard Lewis']
# Michael Stewart : ['Loren Woods', 'Joel Przybilla', 'Todd Fuller', 'Dominic McGuire', 'Calvin Booth']
# Mickael Pietrus : ['Omri Casspi', 'Francisco Garcia', 'Tim Thomas', 'Keith Bogans', 'Alonzo Gee']
# Mike Bibby : ['Raymond Felton', 'Mike Conley', 'Jason Terry', 'Tony Parker', 'Jrue Holiday']
# Mike Conley : ['Darren Collison', 'Jameer Nelson', 'Jrue Holiday', 'Luke Ridnour', 'Jarrett Jack']
# Mike Dunleavy : ['Morris Peterson', 'James Posey', 'Joe Johnson', 'Mike Miller', 'Ryan Gomes']
# Mike James (i) : ['Chucky Atkins', 'Toney Douglas', 'Luther Head', 'Juan Dixon', 'Marko Jaric']
# Mike Miller : ['Mike Dunleavy', 'Joe Johnson', 'O.J. Mayo', 'Morris Peterson', 'Khris Middleton']
# Mike Muscala : ['Quincy Acy', 'Jon Leuer', 'Meyers Leonard', 'D.J. White', 'Brian Cook']
# Mike Scott : ['Brian Cook', 'Andrew Nicholson', 'Matt Bonner', 'Shabazz Muhammad', 'Chase Budinger']
# Mike Wilks : ['Ronnie Price', 'Bostjan Nachbar', 'Donald Sloan', 'Chris Quinn', 'Kevin Ollie']
# Mikki Moore : ['Jeremy Evans', 'Amir Johnson', 'Greg Smith', 'Jelani McCoy', 'Jeff Withey']
# Miles Plumlee : ['Lavoy Allen', 'Jordan Hill', 'Timofey Mozgov', 'Thomas Robinson', 'Aron Baynes']
# Milt Palacio : ['Royal Ivey', 'John Salmons', 'Anthony Johnson', 'Jacque Vaughn', 'Marcus Banks']
# Mirza Teletovic : ['Gary Neal', 'Chase Budinger', 'Mike Scott', 'Reggie Williams (ii)', 'Marcus Morris']
# Mo Williams : ['Randy Foye', 'Luke Ridnour', 'Jamal Crawford', 'Delonte West', 'Jameer Nelson']
# Monta Ellis : ['Tyreke Evans', 'Rodney Stuckey', 'DeMar DeRozan', 'Ron Mercer', 'Larry Hughes']
# Morris Peterson : ['Mike Dunleavy', 'Courtney Lee', 'Joe Johnson', 'Mike Miller', 'James Posey']
# Nate Robinson : ['Leandro Barbosa', 'Marcus Thornton', 'Tim Thomas', 'CJ McCollum', 'Randy Foye']
# Nazr Mohammed : ['Samaki Walker', 'Vladimir Stepania', 'Todd Fuller', 'Kris Humphries', 'Chris Mihm']
# Nenad Krstic : ['Jason Thompson', 'Eddy Curry', 'David West', 'J.J. Hickson', 'Michael Kidd-Gilchrist']
# Nene Hilario : ['Mateen Cleaves', 'Byron Mullens', 'Cedric Henderson', 'DeShawn Stevenson', 'Tariq Abdul-Wahad']
# Nick Collison : ['Jason Thompson', 'Udonis Haslem', 'Tyler Zeller', 'Ed Davis', 'Lorenzen Wright']
# Nick Young : ['Gordan Giricek', 'Juan Dixon', 'Alec Burks', 'Marco Belinelli', 'Trey Burke']
# Nicolas Batum : ['Ryan Anderson', 'Otto Porter', 'Danilo Gallinari', 'Jared Dudley', 'Kelly Olynyk']
# Nikola Pekovic : ['Carl Landry', 'Jason Thompson', 'Kenneth Faried', 'David West', 'Nick Collison']
# Nikola Vucevic : ['Al Jefferson', 'Drew Gooden', 'Jared Sullinger', 'Andrew Bogut', 'Carlos Boozer']
# Norris Cole : ['Austin Rivers', 'John Salmons', "E'Twaun Moore", 'Marcus Banks', 'Eric Maynor']
# O.J. Mayo : ['Bradley Beal', 'Khris Middleton', 'CJ McCollum', 'Victor Oladipo', 'Brandon Knight']
# Omer Asik : ['Dewayne Dedmon', 'Jahidi White', 'Bismack Biyombo', 'Tyson Chandler', 'Anderson Varejao']
# Omri Casspi : ['Marcus Morris', 'Keith Bogans', 'Austin Daye', 'Jumaine Jones', 'Rodney Carney']
# Othella Harrington : ['Chris Wilcox', 'Hakim Warrick', 'Vitaly Potapenko', 'Etan Thomas', 'Melvin Ely']
# Otto Porter : ['Jae Crowder', 'Harrison Barnes', 'Arron Afflalo', 'Courtney Lee', 'Maurice Harkless']
# Pat Garrity : ['Jason Kapono', 'Rasual Butler', 'Mickael Pietrus', 'Arron Afflalo', 'Brian Cook']
# Patrick Beverley : ['Iman Shumpert', 'Mario Chalmers', 'Francisco Garcia', 'Delonte West', 'Luther Head']
# Patrick Patterson : ['Trevor Booker', 'Terrence Jones', 'Dante Cunningham', 'Brian Cook', 'Marreese Speights']
# Patty Mills : ['Jimmer Fredette', 'J.J. Barea', 'Marco Belinelli', 'Ian Clark', 'Shelvin Mack']
# Pau Gasol : ['Chris Bosh', 'Yao Ming', 'Elton Brand', 'Brook Lopez', "Amar'e Stoudemire"]
# Paul George : ['Andre Iguodala', 'Danny Granger', 'Kawhi Leonard', 'Victor Oladipo', 'Chandler Parsons']
# Paul Millsap : ['Joakim Noah', 'Derrick Favors', 'Mason Plumlee', 'Kenneth Faried', 'Cody Zeller']
# Paul Pierce : ['Vince Carter', 'Steve Francis', 'Dirk Nowitzki', 'Kevin Durant', 'Gilbert Arenas']
# Peja Stojakovic : ['Cuttino Mobley', 'Mike Miller', 'Kevin Martin', 'Wesley Matthews', 'Ray Allen']
# Primoz Brezec : ['Josh Powell', 'Brandon Bass', 'Jason Collier', 'Melvin Ely', 'Jake Tsakalidis']
# Quentin Richardson : ['Tim Thomas', 'Michael Redd', 'Vladimir Radmanovic', 'Nate Robinson', 'Rashard Lewis']
# Quincy Acy : ['Mike Muscala', 'Meyers Leonard', 'Jon Leuer', 'Trevor Booker', 'Timofey Mozgov']
# Quincy Pondexter : ["E'Twaun Moore", 'Allen Crabbe', 'Rodney Carney', 'Wayne Ellington', 'Jason Kapono']
# Quinton Ross : ['Trenton Hassell', 'Ira Newble', 'Thabo Sefolosha', 'John Salmons', 'Antoine Wright']
# Raef LaFrentz : ['Marcus Camby', 'Mehmet Okur', 'Roy Hibbert', 'Josh Howard', 'LaMarcus Aldridge']
# Rafer Alston : ['Jannero Pargo', 'Anthony Johnson', 'Eric Maynor', 'Troy Hudson', 'Bryce Drew']
# Raja Bell : ['Dahntay Jones', 'Royal Ivey', 'Antoine Wright', 'Walter McCarty', 'Bostjan Nachbar']
# Rajon Rondo : ['Baron Davis', 'Andre Iguodala', 'Tony Parker', 'Jrue Holiday', 'Brevin Knight']
# Ramon Sessions : ['Rodney Stuckey', 'Darren Collison', 'Jarrett Jack', 'Jeff Teague', 'Mo Williams']
# Randy Foye : ['Mo Williams', 'D.J. Augustin', 'Gordan Giricek', 'Nate Robinson', 'Chucky Atkins']
# Randy Livingston : ['Ricky Davis', 'Milt Palacio', 'Marcus Banks', 'Dorell Wright', 'Alvin Williams']
# Rashard Lewis : ['Tim Thomas', 'Mike Dunleavy', 'Quentin Richardson', 'Vladimir Radmanovic', 'Shandon Anderson']
# Rasho Nesterovic : ['Michael Doleac', 'Chris Mihm', 'Johan Petro', 'Malik Allen', 'Jake Tsakalidis']
# Rasual Butler : ['Jason Kapono', 'Wayne Ellington', 'Rodney Carney', 'Pat Garrity', 'Marcus Morris']
# Ray Allen : ['Cuttino Mobley', 'Jason Terry', 'Gilbert Arenas', 'Jason Richardson', 'Peja Stojakovic']
# Raymond Felton : ['Jrue Holiday', 'Mike Bibby', 'Mike Conley', 'Kemba Walker', 'Brandon Knight']
# Reggie Bullock : ['Quincy Pondexter', 'Ian Clark', 'Cartier Martin', 'John Jenkins', 'Luke Babbitt']
# Reggie Evans : ['Jahidi White', 'Anderson Varejao', 'Omer Asik', 'Zaza Pachulia', 'Jeff Foster']
# Reggie Jackson : ['Jeff Teague', 'Beno Udrih', 'Delonte West', 'Goran Dragic', 'Dennis Schroder']
# Reggie Williams (ii) : ['Chase Budinger', 'Tim Hardaway (ii)', 'Evan Fournier', 'Gary Neal', 'Mike Scott']
# Renaldo Balkman : ['Robert Traylor', 'Trevor Ariza', 'Ryan Bowen', 'Josh McRoberts', 'Eduardo Najera']
# Richard Hamilton : ['DeMar DeRozan', 'Rodney Stuckey', 'Ron Mercer', 'Monta Ellis', 'Cuttino Mobley']
# Richard Jefferson : ['Luol Deng', 'Kobe Bryant', 'Josh Howard', 'Caron Butler', 'Giannis Antetokounmpo']
# Rick Brunson : ['Rafer Alston', 'Kevin Ollie', 'Mateen Cleaves', 'Ish Smith', 'Anthony Johnson']
# Ricky Davis : ['Dion Glover', 'Randy Livingston', 'Lou Williams', 'Tony Delk', 'Marcus Banks']
# Ricky Rubio : ['Jamaal Tinsley', 'Brevin Knight', 'Michael Carter-Williams', 'Jeremy Lin', 'Raymond Felton']
# Robert Covington : ['Patrick Beverley', 'Vladimir Radmanovic', 'Jae Crowder', 'Iman Shumpert', 'Mickael Pietrus']
# Robert Traylor : ['Malik Rose', 'Travis Knight', 'Kelvin Cato', 'Trevor Ariza', 'Renaldo Balkman']
# Robin Lopez : ['Chris Wilcox', 'Jordan Hill', 'Jason Maxiell', 'Tyler Zeller', 'Timofey Mozgov']
# Rodney Carney : ['Marcus Morris', 'Quincy Pondexter', 'Rasual Butler', 'Austin Daye', 'Wayne Ellington']
# Rodney Stuckey : ['Monta Ellis', 'Larry Hughes', 'Ramon Sessions', 'Mo Williams', 'Tyreke Evans']
# Ron Mercer : ['Monta Ellis', 'Richard Hamilton', 'Larry Hughes', 'DeMar DeRozan', 'Caron Butler']
# Ronald Dupree : ['Dahntay Jones', 'Earl Clark', 'Gerald Wallace', 'Kris Humphries', 'Devin Brown']
# Ronald Murray : ['Willie Green', 'Eddie House', 'Juan Dixon', 'Dion Glover', 'Shannon Brown']
# Ronnie Brewer : ['Thaddeus Young', 'Jimmy Butler', 'Marquis Daniels', 'Devin Harris', 'Ruben Patterson']
# Ronnie Price : ['Shannon Brown', 'Mike Wilks', 'Ian Clark', "E'Twaun Moore", 'Chris Quinn']
# Ronny Turiaf : ['Kelvin Cato', 'Timofey Mozgov', 'Robin Lopez', 'Scot Pollard', 'Etan Thomas']
# Roy Hibbert : ['Taj Gibson', 'Derrick Favors', 'Jason Thompson', 'Al Jefferson', 'Chris Kaman']
# Royal Ivey : ['Dahntay Jones', 'John Salmons', 'Milt Palacio', 'Raja Bell', 'Antoine Wright']
# Ruben Patterson : ['Shandon Anderson', 'Bonzi Wells', 'Marquis Daniels', 'Corey Maggette', 'Brad Miller']
# Rudy Gay : ['Jason Richardson', 'Victor Oladipo', 'Caron Butler', 'Tyreke Evans', 'O.J. Mayo']
# Rudy Gobert : ['Joakim Noah', 'Mason Plumlee', 'Steven Adams', 'Jonas Valanciunas', 'Kenneth Faried']
# Russell Westbrook : ['John Wall', 'Steve Francis', 'Tyreke Evans', 'Andre Miller', 'Allen Iverson']
# Ryan Anderson : ['Nicolas Batum', 'Danilo Gallinari', 'Vladimir Radmanovic', 'Kelly Olynyk', 'Jared Dudley']
# Ryan Bowen : ['Eduardo Najera', 'Greg Buckner', 'Adrian Griffin', 'Matt Barnes', 'Eddie Robinson']
# Ryan Gomes : ['Desmond Mason', 'Mike Dunleavy', 'Harrison Barnes', 'Marvin Williams', 'Markieff Morris']
# Ryan Hollins : ['Solomon Jones', 'Hasheem Thabeet', 'Jake Voskuhl', 'Hilton Armstrong', 'Steven Hunter']
# Samaki Walker : ['Jake Tsakalidis', 'Nazr Mohammed', 'Donnell Harvey', 'Brian Skinner', 'Chris Mihm']
# Sasha Pavlovic : ['John Salmons', 'C.J. Miles', 'Antoine Wright', "E'Twaun Moore", 'Rodney Carney']
# Sasha Vujacic : ['Daequan Cook', 'Chris Quinn', 'James Jones', 'Wayne Ellington', 'Jason Kapono']
# Scot Pollard : ['Eduardo Najera', 'Kelvin Cato', 'Anderson Varejao', 'Tony Battie', 'Ronny Turiaf']
# Scott Padgett : ['Austin Croshere', 'Devean George', 'Devin Brown', 'Jumaine Jones', 'Brian Cardinal']
# Sebastian Telfair : ['Austin Rivers', 'Norris Cole', 'Keyon Dooling', 'Mo Williams', 'Jerryd Bayless']
# Serge Ibaka : ['JaVale McGee', 'Jonas Valanciunas', 'Andrew Bynum', 'Roy Hibbert', 'Joakim Noah']
# Shabazz Muhammad : ['Mike Scott', 'Derrick Williams', 'Reggie Williams (ii)', 'Andrew Nicholson', 'Alec Burks']
# Shammond Williams : ['Brian Cardinal', 'Earl Boykins', 'Kevin Ollie', 'Jacque Vaughn', 'Jerryd Bayless']
# Shandon Anderson : ['Tim Thomas', 'Marquis Daniels', 'Tony Allen', 'Eddie Robinson', 'Damien Wilkins']
# Shane Battier : ['James Posey', 'Josh Howard', 'Morris Peterson', 'Tayshaun Prince', 'Mike Dunleavy']
# Shannon Brown : ['Ronnie Price', "E'Twaun Moore", 'Keyon Dooling', 'Bostjan Nachbar', 'C.J. Miles']
# Shareef Abdur-Rahim : ['Carmelo Anthony', 'Chris Bosh', 'Keith Van Horn', "Amar'e Stoudemire", 'Pau Gasol']
# Shavlik Randolph : ['Kyrylo Fesenko', 'Lou Amundson', 'Kosta Koufos', 'Vladimir Stepania', 'Hamed Haddadi']
# Shawn Marion : ['Josh Howard', 'Al Horford', 'Luol Deng', 'LaMarcus Aldridge', 'Dirk Nowitzki']
# Shelden Williams : ['Josh Powell', 'Donnell Harvey', 'Solomon Jones', 'Timofey Mozgov', 'Brian Skinner']
# Shelvin Mack : ['J.J. Barea', 'Eric Maynor', 'A.J. Price', "E'Twaun Moore", 'Beno Udrih']
# Solomon Hill : ['Tony Snell', 'Kyle Singler', 'Landry Fields', 'Thabo Sefolosha', 'Arron Afflalo']
# Solomon Jones : ['Ryan Hollins', 'Hilton Armstrong', 'Josh Powell', 'Shelden Williams', 'Kosta Koufos']
# Speedy Claxton : ['Marquis Daniels', 'Bobby Jackson', 'Jeremy Lin', 'Kyle Lowry', 'Devin Harris']
# Spencer Hawes : ['Alex Len', 'Andray Blatche', 'Darius Miles', 'Channing Frye', 'J.J. Hickson']
# Stanislav Medvedenko : ['Lee Nailon', 'Travis Outlaw', 'Chris Crawford', 'Michael Doleac', 'Marreese Speights']
# Stephen Curry : ['Kyrie Irving', 'Gilbert Arenas', 'Jason Terry', 'Ray Allen', 'Isaiah Thomas']
# Stephen Graham : ['John Jenkins', 'Ian Clark', 'Shannon Brown', 'Matt Carroll', 'Ronnie Price']
# Stephen Jackson : ['Erick Strickland', 'Marko Jaric', 'Delonte West', 'Iman Shumpert', 'Jamal Crawford']
# Stephon Marbury : ['Deron Williams', 'Gilbert Arenas', 'Jason Terry', 'Mike Bibby', 'Andre Miller']
# Steve Blake : ['Matthew Dellavedova', 'Bryce Drew', 'Eric Maynor', 'Steve Nash', 'Matt Maloney']
# Steve Francis : ['Paul Pierce', 'Russell Westbrook', 'Gilbert Arenas', 'Brandon Roy', 'Vince Carter']
# Steve Nash : ['Steve Blake', 'Beno Udrih', 'Antonio Daniels', 'Goran Dragic', 'Delonte West']
# Steve Novak : ['Travis Diener', 'Reggie Bullock', 'John Jenkins', 'J.J. Redick', 'Allen Crabbe']
# Steven Adams : ['Mason Plumlee', 'Brendan Haywood', 'Ed Davis', 'Derrick Favors', 'Andris Biedrins']
# Steven Hunter : ['Jason Maxiell', 'Robin Lopez', 'Jelani McCoy', 'Lou Amundson', "Jermaine O'Neal"]
# Stromile Swift : ['Keon Clark', 'Tyrus Thomas', 'Tony Battie', 'Derrick Favors', 'Kwame Brown']
# Taj Gibson : ['Keon Clark', 'Ed Davis', 'Roy Hibbert', 'JaVale McGee', 'Cody Zeller']
# Tariq Abdul-Wahad : ['Cedric Henderson', 'Dion Glover', 'Walter McCarty', 'Devin Brown', 'Al Harrington']
# Tayshaun Prince : ['Mike Dunleavy', 'Harrison Barnes', 'George Hill', 'Ryan Gomes', 'Joe Johnson']
# Terrence Jones : ['Patrick Patterson', 'Trevor Booker', 'Michael Kidd-Gilchrist', 'Cody Zeller', 'Tobias Harris']
# Terrence Ross : ['Jodie Meeks', 'Tim Hardaway (ii)', 'Brandon Rush', 'Courtney Lee', 'Chase Budinger']
# Thabo Sefolosha : ['Landry Fields', 'Al-Farouq Aminu', 'Luke Walton', 'Kent Bazemore', 'John Salmons']
# Thaddeus Young : ['Rashard Lewis', 'Tobias Harris', 'Ryan Gomes', 'Markieff Morris', 'Luol Deng']
# Thomas Robinson : ['Kris Humphries', 'Miles Plumlee', 'Shelden Williams', 'Johan Petro', 'Donnell Harvey']
# Tiago Splitter : ['Mason Plumlee', 'Carl Landry', 'Craig Smith', 'Trevor Booker', 'Ed Davis']
# Tim Duncan : ['Elton Brand', 'Yao Ming', 'Blake Griffin', 'Dwight Howard', 'Anthony Davis']
# Tim Hardaway (ii) : ['Terrence Ross', 'Chase Budinger', 'Evan Fournier', 'Jodie Meeks', 'Anthony Morrow']
# Tim Thomas : ['Corey Maggette', 'Shandon Anderson', 'Rashard Lewis', 'Nate Robinson', 'Mickael Pietrus']
# Timofey Mozgov : ['Aron Baynes', 'Aaron Gray', 'Jordan Hill', "Kyle O'Quinn", 'Dewayne Dedmon']
# Tobias Harris : ['Wilson Chandler', 'Charlie Villanueva', 'Michael Kidd-Gilchrist', 'Derrick Williams', 'Ryan Gomes']
# Todd Fuller : ['Josh Powell', 'Nazr Mohammed', 'Brandon Bass', 'Samaki Walker', 'Kris Humphries']
# Toney Douglas : ['Juan Dixon', 'A.J. Price', 'C.J. Watson', 'Luther Head', 'Mike James (i)']
# Tony Allen : ['Marquis Daniels', 'Shandon Anderson', 'Trevor Ariza', 'Alonzo Gee', 'Marcus Banks']
# Tony Battie : ['Keon Clark', 'Lorenzen Wright', 'Travis Knight', 'Stromile Swift', 'Dan Gadzuric']
# Tony Delk : ['Dion Glover', 'Eddie House', 'Juan Dixon', 'Alvin Williams', 'Beno Udrih']
# Tony Parker : ['Mike Bibby', 'Mike Conley', 'Jrue Holiday', 'Jameer Nelson', 'Jason Terry']
# Tony Snell : ['Allen Crabbe', 'Kyle Singler', 'Wayne Ellington', 'Jodie Meeks', 'Solomon Hill']
# Tracy McGrady : ['Kobe Bryant', 'Luol Deng', 'Josh Howard', 'Richard Jefferson', 'LaMarcus Aldridge']
# Travis Diener : ['Chris Quinn', 'Damon Jones', 'J.J. Redick', 'Steve Novak', 'Marco Belinelli']
# Travis Knight : ['Robert Traylor', 'Jake Tsakalidis', 'Mark Blount', 'Tony Battie', 'Andray Blatche']
# Travis Outlaw : ['Gerald Wallace', 'Stanislav Medvedenko', 'C.J. Miles', 'Kris Humphries', 'Chris Crawford']
# Trenton Hassell : ['Quinton Ross', 'Thabo Sefolosha', 'Cedric Henderson', 'Kyle Singler', 'Keith Bogans']
# Trevor Ariza : ['Tony Allen', 'Robert Traylor', 'Gerald Wallace', 'Malik Rose', 'Matt Barnes']
# Trevor Booker : ['Ed Davis', 'Patrick Patterson', 'Eduardo Najera', 'Dan Gadzuric', 'Dante Cunningham']
# Trey Burke : ['Randy Foye', 'Jamal Crawford', 'D.J. Augustin', 'Dion Waiters', 'Dennis Schroder']
# Tristan Thompson : ['Jason Thompson', 'Derrick Favors', 'Al Jefferson', 'Drew Gooden', 'Udonis Haslem']
# Troy Daniels : ['Travis Diener', 'Steve Novak', 'Jordan Hamilton', 'Marco Belinelli', 'J.J. Redick']
# Troy Hudson : ['Earl Boykins', 'Tony Delk', 'Eddie House', 'Carlos Arroyo', 'Rafer Alston']
# Troy Murphy : ['Drew Gooden', 'Kenny Thomas', 'David West', 'Charlie Villanueva', 'Marvin Williams']
# Ty Lawson : ['Jose Calderon', 'Isaiah Thomas', 'Jameer Nelson', 'Darren Collison', 'Devin Harris']
# Tyler Hansbrough : ['Glen Davis', 'Marc Jackson', 'Hakim Warrick', 'Marreese Speights', 'Zaza Pachulia']
# Tyler Zeller : ['Marreese Speights', 'J.J. Hickson', 'Hakim Warrick', 'Robin Lopez', 'Darius Songaila']
# Tyreke Evans : ['Monta Ellis', 'Victor Oladipo', 'Rodney Stuckey', 'Jason Richardson', 'Rudy Gay']
# Tyronn Lue : ['Keyon Dooling', 'J.J. Barea', 'Damon Jones', 'Chris Quinn', 'Bryce Drew']
# Tyrus Thomas : ['Stromile Swift', 'Keon Clark', 'Derrick Favors', 'Tyson Chandler', 'Darius Miles']
# Tyson Chandler : ['Jamaal Magloire', 'Derrick Favors', 'Brendan Haywood', 'Keon Clark', 'Andrew Bynum']
# Udonis Haslem : ['Nick Collison', 'Jason Thompson', 'Tristan Thompson', 'Drew Gooden', 'Jamaal Magloire']
# Victor Oladipo : ['O.J. Mayo', 'Bradley Beal', 'Jrue Holiday', 'Brandon Knight', 'Rudy Gay']
# Vince Carter : ['Paul Pierce', 'Brandon Roy', 'Steve Francis', 'Kevin Durant', 'Carmelo Anthony']
# Vitaly Potapenko : ['Chris Mihm', 'Kwame Brown', 'John Wallace', 'Othella Harrington', 'Lorenzen Wright']
# Vladimir Radmanovic : ['Kyle Korver', 'Mike Dunleavy', 'Morris Peterson', 'Quentin Richardson', 'Francisco Garcia']
# Vladimir Stepania : ['Nazr Mohammed', 'Loren Woods', 'Todd Fuller', 'Earl Clark', 'Michael Stewart']
# Wally Szczerbiak : ['Peja Stojakovic', 'Ray Allen', 'Cuttino Mobley', 'Josh Howard', 'Danny Granger']
# Walter McCarty : ['Brian Scalabrine', 'Devean George', 'Tariq Abdul-Wahad', 'Raja Bell', 'Dahntay Jones']
# Wang Zhizhi : ['Jason Collier', 'Stephen Graham', 'Chris Crawford', 'Cartier Martin', 'Matt Carroll']
# Wayne Ellington : ['Jason Kapono', 'Marco Belinelli', "E'Twaun Moore", 'Rasual Butler', 'Allen Crabbe']
# Wesley Johnson : ['Kyle Singler', 'Brandon Rush', 'Keith Bogans', 'Ben McLemore', 'Marcus Morris']
# Wesley Matthews : ['Khris Middleton', 'Morris Peterson', 'O.J. Mayo', 'CJ McCollum', 'Chandler Parsons']
# Will Barton : ['Austin Daye', 'Marcus Morris', 'Omri Casspi', 'Kent Bazemore', 'Jeremy Lamb']
# Willie Green : ['Ronald Murray', 'Eddie House', 'Keyon Dooling', 'Shannon Brown', 'Avery Bradley']
# Wilson Chandler : ['Andrea Bargnani', 'Charlie Villanueva', 'Tobias Harris', 'Michael Beasley', 'Markieff Morris']
# Xavier Henry : ['Shannon Brown', 'Dahntay Jones', 'Austin Rivers', 'Antoine Wright', 'DeShawn Stevenson']
# Yao Ming : ['Pau Gasol', 'Chris Bosh', 'Marc Gasol', 'Elton Brand', 'Anthony Davis']
# Yi Jianlian : ['Channing Frye', 'Chris Mihm', 'Kwame Brown', 'Marcus Fizer', 'Spencer Hawes']
# Zach Randolph : ['Drew Gooden', 'David West', 'Al Jefferson', 'Troy Murphy', 'Charlie Villanueva']
# Zaza Pachulia : ['Kwame Brown', 'Kenny Thomas', 'Lorenzen Wright', 'Glen Davis', 'J.J. Hickson']
# Zeljko Rebraca : ['Aron Baynes', 'Timofey Mozgov', 'Darius Songaila', 'Lawrence Funderburke', 'Francisco Elson']
# Zendon Hamilton : ["Mamadou N'Diaye", 'Todd Fuller', 'Nazr Mohammed', 'Jason Collier', 'Jeff Adrien']

# %%
hey = list(df.index[indices[i][1:]])
