# %% [markdown]
# # Implement scripts and functions

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

from sklearn.linear_model import Lasso, LinearRegression, Ridge

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %reload_ext autoreload

# %% [markdown]
# ## Read in file, clean functions and perform rolling means

# %%
import preprocessor, league_table, soccer_model
import rolling_means as rmeans
import soccer_linear_model as footy_lin_mod
import Team_Dominancy as team_dom

# %%
csvfile = '../data/FootballEurope/FootballEurope.csv' 
roll_df = rmeans.final_df_rolling_means(csvfile)
# Out:
# /Users/CEO/DSI/dsi-CapstoneProj/src/rolling_means.py:28: DtypeWarning: Columns (39,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   ready_df = clean_data(csv_file)

# %%
roll_df.head()
# Out:
#                                      CornersTotalFT  DispossessedFT  \
# days_after_opener game_id Team
# 0 days            232     Reading               NaN             NaN
#                           Stoke                 NaN             NaN
#                   292     QPR                   NaN             NaN
#                           Swansea               NaN             NaN
#                   293     Liverpool             NaN             NaN
#
#                                      DribbleSuccessFT  DribbledPastFT  \
# days_after_opener game_id Team
# 0 days            232     Reading                 NaN             NaN
#                           Stoke                   NaN             NaN
#                   292     QPR                     NaN             NaN
#                           Swansea                 NaN             NaN
#                   293     Liverpool               NaN             NaN
#
#                                      DribblesAttemptedFT  DribblesWonFT  \
# days_after_opener game_id Team
# 0 days            232     Reading                    NaN            NaN
#                           Stoke                      NaN            NaN
#                   292     QPR                        NaN            NaN
#                           Swansea                    NaN            NaN
#                   293     Liverpool                  NaN            NaN
#
#                                      FormationCode  FoulsCommitedFT  \
# days_after_opener game_id Team
# 0 days            232     Reading              NaN              NaN
#                           Stoke                NaN              NaN
#                   292     QPR                  NaN              NaN
#                           Swansea              NaN              NaN
#                   293     Liverpool            NaN              NaN
#
#                                      InterceptionsFT  OffsidesCaughtFT  \
# days_after_opener game_id Team
# 0 days            232     Reading                NaN               NaN
#                           Stoke                  NaN               NaN
#                   292     QPR                    NaN               NaN
#                           Swansea                NaN               NaN
#                   293     Liverpool              NaN               NaN
#
#                                      PassSuccessFT  PassesKeyFT  PossessionFT  \
# days_after_opener game_id Team
# 0 days            232     Reading              NaN          NaN           NaN
#                           Stoke                NaN          NaN           NaN
#                   292     QPR                  NaN          NaN           NaN
#                           Swansea              NaN          NaN           NaN
#                   293     Liverpool            NaN          NaN           NaN
#
#                                      RatingsFT  ShotsBlockedFT  \
# days_after_opener game_id Team
# 0 days            232     Reading          NaN             NaN
#                           Stoke            NaN             NaN
#                   292     QPR              NaN             NaN
#                           Swansea          NaN             NaN
#                   293     Liverpool        NaN             NaN
#
#                                      ShotsOnTargetFT  ShotsTotalFT  \
# days_after_opener game_id Team
# 0 days            232     Reading                NaN           NaN
#                           Stoke                  NaN           NaN
#                   292     QPR                    NaN           NaN
#                           Swansea                NaN           NaN
#                   293     Liverpool              NaN           NaN
#
#                                      TackleSuccessFT  TacklesTotalFT  \
# days_after_opener game_id Team
# 0 days            232     Reading                NaN             NaN
#                           Stoke                  NaN             NaN
#                   292     QPR                    NaN             NaN
#                           Swansea                NaN             NaN
#                   293     Liverpool              NaN             NaN
#
#                                      TeamCode  at_home  Total_GoalsFT  GoalFT  \
# days_after_opener game_id Team
# 0 days            232     Reading         NaN      NaN            NaN       1
#                           Stoke           NaN      NaN            NaN       1
#                   292     QPR             NaN      NaN            NaN       0
#                           Swansea         NaN      NaN            NaN       5
#                   293     Liverpool       NaN      NaN            NaN       0
#
#                                      XResults
# days_after_opener game_id Team
# 0 days            232     Reading           0
#                           Stoke             0
#                   292     QPR              -5
#                           Swansea           5
#                   293     Liverpool        -3

# %% [markdown]
# ## Linear Model

# %%
model_df = footy_lin_mod.get_model_df(csvfile)
# Out:
# /Users/CEO/DSI/dsi-CapstoneProj/src/rolling_means.py:28: DtypeWarning: Columns (39,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   ready_df = clean_data(csv_file)

# %%
model_df.head()
# Out:
#          Home_CornersTotalFT  Home_DispossessedFT  Home_DribbleSuccessFT  \
# game_id
# 251                      6.4                 16.6                 48.258
# 252                      4.8                 11.4                 50.396
# 253                      6.4                 13.2                 47.008
# 254                      6.2                 16.0                 43.980
# 257                      2.6                 11.2                 28.630
#
#          Home_DribbledPastFT  Home_DribblesAttemptedFT  Home_DribblesWonFT  \
# game_id
# 251                      5.2                      26.0                13.4
# 252                      6.0                       9.8                 5.0
# 253                      4.6                      13.6                 6.6
# 254                      7.2                      19.6                 9.4
# 257                      7.8                       9.8                 2.8
#
#          Home_FormationCode  Home_FoulsCommitedFT  Home_InterceptionsFT  \
# game_id
# 251                     2.0                   8.0                  19.6
# 252                     3.0                  13.6                  11.6
# 253                     2.4                   8.8                  18.0
# 254                     1.2                  12.0                  11.6
# 257                     3.0                  13.8                  14.8
#
#          Home_OffsidesCaughtFT  Home_PassSuccessFT  Home_PassesKeyFT  \
# game_id
# 251                        1.0              77.688              13.0
# 252                        2.0              71.194              15.4
# 253                        1.4              76.394              11.0
# 254                        1.6              76.554              12.4
# 257                        2.8              58.466               8.0
#
#          Home_PossessionFT  Home_ShotsBlockedFT  Home_ShotsOnTargetFT  \
# game_id
# 251                 57.840                  4.8                   4.6
# 252                 51.582                  5.6                   6.4
# 253                 49.962                  4.4                   8.2
# 254                 55.010                  4.4                   4.2
# 257                 40.936                  3.2                   3.2
#
#          Home_ShotsTotalFT  Home_TackleSuccessFT  Home_TacklesTotalFT  \
# game_id
# 251                   17.0                83.954                 29.2
# 252                   20.2                76.824                 22.4
# 253                   16.2                77.448                 20.4
# 254                   17.8                74.902                 28.8
# 257                   10.6                77.312                 29.2
#
#          Home_Total_GoalsFT  Home_GoalFT  Away_CornersTotalFT  \
# game_id
# 251                     2.2          1.0                  4.2
# 252                     2.8          3.0                  4.2
# 253                     3.8          1.0                  6.6
# 254                     2.8          5.0                  4.8
# 257                     1.8          2.0                  5.6
#
#          Away_DispossessedFT  Away_DribbleSuccessFT  Away_DribbledPastFT  \
# game_id
# 251                     12.8                 47.598                  5.0
# 252                     12.8                 31.666                  5.4
# 253                     16.0                 53.422                  5.6
# 254                     10.8                 51.722                  7.6
# 257                     12.6                 29.500                  5.2
#
#          Away_DribblesAttemptedFT  Away_DribblesWonFT  Away_FormationCode  \
# game_id
# 251                          15.6                 7.6                 2.0
# 252                          12.0                 4.2                 1.0
# 253                          13.6                 7.4                 2.2
# 254                           8.8                 4.6                 2.6
# 257                          13.8                 5.0                 0.8
#
#          Away_FoulsCommitedFT  Away_InterceptionsFT  Away_OffsidesCaughtFT  \
# game_id
# 251                      12.8                  16.2                    1.2
# 252                       7.8                  20.0                    1.6
# 253                       9.6                  12.0                    1.6
# 254                      14.4                   9.0                    1.4
# 257                      14.0                  12.0                    1.4
#
#          Away_PassSuccessFT  Away_PassesKeyFT  Away_PossessionFT  \
# game_id
# 251                  73.138              11.8             53.560
# 252                  72.844               9.8             48.940
# 253                  75.128              11.2             53.994
# 254                  60.628              10.4             47.062
# 257                  77.166               9.8             53.004
#
#          Away_ShotsBlockedFT  Away_ShotsOnTargetFT  Away_ShotsTotalFT  \
# game_id
# 251                      3.8                   4.8               15.2
# 252                      3.0                   4.2               13.4
# 253                      5.2                   6.4               16.4
# 254                      3.2                   4.2               14.2
# 257                      3.8                   5.0               13.8
#
#          Away_TackleSuccessFT  Away_TacklesTotalFT  Away_GoalFT
# game_id
# 251                    78.808                 22.4          2.0
# 252                    82.596                 27.6          1.0
# 253                    85.138                 30.0          2.0
# 254                    70.432                 24.6          2.0
# 257                    80.828                 24.2          0.0

# %%
lassoL1 = Lasso(alpha=0.05, tol=.0002)
LassoPred = footy_lin_mod.linear_model(model_df, lassoL1, 0.25, 'MinMax')
# Out:
# Model:Lasso(alpha=0.05, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0002, warm_start=False)
# R-squared:0.005729643654268868
# Mean Abs Error:0.11595606435190464
# RMSE:0.14558682925863445

# %%
linreg = LinearRegression()
LinRegPred = footy_lin_mod.linear_model(model_df, linreg, 0.25, 'MinMax')
# Out:
# Model:LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
# R-squared:0.2820748736621652
# Mean Abs Error:0.09742704684556903
# RMSE:0.12300451097887803

# %%
ridgeL2 = Ridge(alpha=0.005)
RidgePred = footy_lin_mod.linear_model(model_df, ridgeL2, 0.25, 'MinMax')
# Out:
# Model:Ridge(alpha=0.005, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)
# R-squared:0.2821343553996264
# Mean Abs Error:0.0974253717028902
# RMSE:0.12299941527090369

# %% [markdown]
# # Team Dominancy

# %%
team_dom.dominancy_at_home(csvfile)
# Out:
# /Users/CEO/DSI/dsi-CapstoneProj/src/Team_Dominancy.py:25: DtypeWarning: Columns (39,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = clean_data(csv_file)

# %%
team_dom.dominancy_when_away(csvfile)
# Out:
# /Users/CEO/DSI/dsi-CapstoneProj/src/Team_Dominancy.py:49: DtypeWarning: Columns (39,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = clean_data(csv_file)
